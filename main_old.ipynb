# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define filepaths
path_coe = 'data/COEBiddingResultsPrices.csv'
path_deregistered = 'data/MotorVehiclesDeRegisteredUnderVehicleQuotaSystemMonthly.csv'
path_registered = 'data/NewRegistrationOfMotorVehiclesUnderVehicleQuotaSystemMonthly.csv'
path_cpi = 'data/outputFile.xlsx'
path_nom_household = 'data/NominalChangeinAverageMonthlyHouseholdEmploymentIncomePerHouseholdMemberExcludingEmployerCPFContributionsAmongResidentEmployedHouseholdsbyDecilesHouseholdEmploymentIncomeAnnual20002024.csv'
#path_real_household = 'data/RealChangeinMonthlyHouseholdEmploymentIncomePerHouseholdMemberExcludingEmployerCPFContributionsAmongResidentEmployedHouseholdsatSelectedPercentilesHouseholdEmploymentIncomeAnnual20002024.csv'
#path_core_inflation = 'data/MAS Core Inflation.xlsx'

# Load datasets
coe = pd.read_csv(path_coe, thousands=',') #thousands separator causing issues
deregistered = pd.read_csv(path_deregistered)
registered = pd.read_csv(path_registered)
cpi = pd.read_excel(path_cpi, sheet_name='T7', skiprows=10) #the only xlsx file
nom_household = pd.read_csv(path_nom_household)
#real_household = pd.read_csv(path_real_household)
#inflation = pd.read_excel(path_core_inflation)

def transpose_df(df):
    df_t = df.transpose()
    df_t.columns = df_t.iloc[0] #declare header
    df_t = df_t[1:] #remove extra header
    df_t.reset_index(inplace=True)
    df_t.rename_axis(None, axis=1, inplace=True) #index was called "Data Series"
    return df_t

# Function to convert date format to YYYY-MM in digits
def convert_date_format(x, original_months, converted_months, index_monthstart, index_yearend):
    ref_dict = dict(zip(original_months, converted_months))
    this_date = x[index_monthstart:] #start the search from the 5th character to skip the year and space
    return f'{x[:index_yearend]}-{ref_dict[this_date]}'

# (OLD) Function to rebase values to their corresponding month in a base year
def rebase_index_old(df, year_base, year_start, year_end_excl, label_time, label_value, list_months): #only for unique year-months
    list_years = [i for i in range(year_start,year_end_excl)]
    for month in list_months:
        base_year_month_value = float(df.loc[df[label_time] == f'{year_base}-{month}',label_value].iloc[0])
        for year in list_years:
            try:
                current_value = float(df.loc[df[label_time] == f'{year}-{month}',label_value].iloc[0])
                rebased_value = round((current_value / base_year_month_value) * 100,3)
                df.loc[df[label_time] == f'{year}-{month}', f'{label_value}_rebased'] = rebased_value
            except: #dates may not be found
                print(f'Error for {year} {month}: {df.loc[df[str(label_time)] == f'{year}-{month}']}')
                pass
    return df

# (NEW) Returns the rebased value for a single row, using specifc date format YYYY-MM
'''
def rebase_index(row, staticdf, year_base, label_time, label_value, label_category=True): #optional label_category just for coe
    value = row[label_value]
    month = row[label_time][5:]
    #print(f'{month}: {value}')
    if label_category==True: #no category label, no need secondary check
        #print('no secondary condition')
        value_base = float(staticdf.loc[staticdf[label_time] == f'{year_base}-{month}', label_value].iloc[0])
        #print(value_base)
        return round(value/value_base*100,3)
    else:
        value_base = float(staticdf.loc[(staticdf[label_time] == f'{year_base}-{month}') & (staticdf[label_category] == row[label_category]), label_value].iloc[0])
        #print(f'base value: {value_base}')
        return round(value/value_base*100,3)
'''
def rebase_index(row, staticdf, year_base, label_time, label_value, label_category=True, month_base=True): #optional label_category just for coe
    value = row[label_value]
    if month_base==True: # if no value input, means map month to month. Otherwise, use the input as base month
        month_base = row[label_time][5:]
        print(f'no month_base input. {year_base}-{month_base}: {value}')
    
    if label_category==True: #no category label, no need secondary check
        #print('no secondary condition')
        value_base = float(staticdf.loc[staticdf[label_time] == f'{year_base}-{month_base}', label_value].iloc[0])
        #print(value_base)
        return round(value/value_base*100,3)
    else:
        value_base = float(staticdf.loc[(staticdf[label_time] == f'{year_base}-{month_base}') & (staticdf[label_category] == row[label_category]), label_value].iloc[0])
        #print(f'base value: {value_base}')
        return round(value/value_base*100,3)
    
def get_common_dates(df_list, date_col_name):
    df1 = df_list[0]
    common_dates = [date for date in df1[date_col_name].to_list()]
    for each_other_df in df_list[1:]:
        for date in common_dates:
            if date not in each_other_df[date_col_name].to_list():
                common_dates.remove(date)
    return common_dates

def basicprep_cpi(cpi, index_monthstart, index_yearend):
    cpi_t = transpose_df(cpi)
    cpi_t.rename(columns={'index': 'month'}, inplace=True)
    cpi_mainmetrics = cpi_t.loc[:, ['month','All Items']] #only interested in 'All Items'
    cpi_mainmetrics_sorted = cpi_mainmetrics[::-1] #reverse the order to have earliest month first

    # Cut off at earliest date of coe dataset
    index_of_earliestdate = cpi_mainmetrics_sorted[cpi_mainmetrics_sorted['month'] == '2010 Jan'].index[0]
    cpi_mainmetrics_sorted_earliestdate = cpi_mainmetrics_sorted.loc[index_of_earliestdate:]

    # Convert date format to YYYY-MM
    text_months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    numerical_months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    cpi_mainmetrics_sorted_earliestdate.loc[:,'month'] = cpi_mainmetrics_sorted_earliestdate.loc[:,'month'].apply(convert_date_format, args=(text_months, numerical_months, index_monthstart, index_yearend))
    
    # Re-base to 2010 months
    #cpi_mainmetrics_sorted_earliestdate_rebased = rebase_index_old(cpi_mainmetrics_sorted_earliestdate, 2010, 2010, 2026, 'month', 'All Items', numerical_months)
    #cpi_mainmetrics_sorted_earliestdate['cpi_reindexed_monthly'] = cpi_mainmetrics_sorted_earliestdate.apply(rebase_index, axis=1, args=(cpi_mainmetrics_sorted_earliestdate.copy(), 2010, 'month', 'All Items'))
    
    # Re-base to 2010-01
    cpi_mainmetrics_sorted_earliestdate['cpi_reindexed_2010-01'] = cpi_mainmetrics_sorted_earliestdate.apply(rebase_index, axis=1, args=(cpi_mainmetrics_sorted_earliestdate.copy(), 2010, 'month', 'All Items', True, 1))

    # Convert month column to datetime
    cpi_mainmetrics_sorted_earliestdate['month'] = pd.to_datetime(cpi_mainmetrics_sorted_earliestdate['month'], format='%Y-%m')

    return cpi_mainmetrics_sorted_earliestdate

def basicprep_coe(coe):
    # Cut off at last date of Nov 2025
    index_of_2025Nov = coe[coe['month'] == '2025-11'].index[-1] #get the last occurrence
    coe_nov25 = coe.loc[:index_of_2025Nov]

    # Average bids 1 and 2
    coe_nov25_bidavg = coe_nov25.groupby(['month','vehicle_class']).mean().reset_index().drop(columns=['bidding_no'])

    # Flatten multiindex columns
    coe_nov25_bidavg.columns = coe_nov25_bidavg.columns.to_flat_index()
    #coe_nov25_bidavg.to_csv('temp.csv')

    # Index COE premiums to 2010 values
    staticdf = coe_nov25_bidavg.copy()
    coe_nov25_bidavg['coe_indexed_monthly'] = coe_nov25_bidavg.apply(rebase_index, axis=1, args=(staticdf, 2010, 'month', 'premium', 'vehicle_class'))

    # Index COE premiums to 2010-01
    coe_nov25_bidavg['coe_indexed_2010-01'] = coe_nov25_bidavg.apply(rebase_index, axis=1, args=(staticdf, 2010, 'month', 'premium', 'vehicle_class', 1))

    # Convert month column to datetime
    coe_nov25_bidavg['month'] = pd.to_datetime(coe_nov25_bidavg['month'], format='%Y-%m')
    return coe_nov25_bidavg

def basicprep_vehregs(df, index_monthstart, index_yearend):
    df_t = transpose_df(df)
    df_t.rename(columns={'index': 'month', '    Category A: Cars':'Category A', '    Category B: Cars':'Category B', '    Category D: Motorcycles & Scooters':'Category D'}, inplace=True)
    #print(df_t.columns) #discovered the leading spaces
    df_mainmetrics = df_t.loc[:, ['month','Category A', 'Category B', 'Category D']]

    # Convert date format to YYYY-MM
    text_months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    numerical_months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    df_mainmetrics.loc[:,'month'] = df_mainmetrics.loc[:,'month'].apply(convert_date_format, args=(text_months, numerical_months, index_monthstart, index_yearend))
    
    # Convert month column to datetime and other columns to int
    #df_mainmetrics = df_mainmetrics.astype({'month': 'datetime64[ns]', 'Category A': int, 'Category B': int, 'Category D': int}) #error caused by a '-' value
    df_mainmetrics = df_mainmetrics.replace('-', 0) # for the specific error case
    df_mainmetrics['month'] = pd.to_datetime(df_mainmetrics['month'], format='%Y-%m')
    df_mainmetrics['Category A'] = df_mainmetrics['Category A'].fillna(0).astype(int)
    df_mainmetrics['Category B'] = df_mainmetrics['Category B'].fillna(0).astype(int)
    df_mainmetrics['Category D'] = df_mainmetrics['Category D'].fillna(0).astype(int)
    return df_mainmetrics
# Out:
#   Cell In[50], line 113
#     cpi_mainmetrics_sorted_earliestdate['cpi_reindexed_2010-01'] = cpi_mainmetrics_sorted_earliestdate.apply(rebase_index, axis=1, args=(cpi_mainmetrics_sorted_earliestdate.copy(), 2010, 'month', 'All Items', True, 01))
#                                                                                                                                                                                                                        ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
# CPI dataset
df_cpi = basicprep_cpi(cpi, 5, 4)
# Out:
# no month_base input. 2010-01: 73.64
# no month_base input. 2010-02: 73.771
# no month_base input. 2010-03: 74
# no month_base input. 2010-04: 74.596
# no month_base input. 2010-05: 75.025
# no month_base input. 2010-06: 74.662
# no month_base input. 2010-07: 75.261
# no month_base input. 2010-08: 75.608
# no month_base input. 2010-09: 75.678
# no month_base input. 2010-10: 75.991
# no month_base input. 2010-11: 76.243
# no month_base input. 2010-12: 76.692
# no month_base input. 2010-01: 77.517
# no month_base input. 2010-02: 77.549
# no month_base input. 2010-03: 77.623
# no month_base input. 2010-04: 78.449
# no month_base input. 2010-05: 78.348
# no month_base input. 2010-06: 78.535
# no month_base input. 2010-07: 79.317
# no month_base input. 2010-08: 79.888
# no month_base input. 2010-09: 79.754
# no month_base input. 2010-10: 80.066
# no month_base input. 2010-11: 80.512
# no month_base input. 2010-12: 80.898
# no month_base input. 2010-01: 81.34
# no month_base input. 2010-02: 81.262
# no month_base input. 2010-03: 81.821
# no month_base input. 2010-04: 82.245
# no month_base input. 2010-05: 82.418
# no month_base input. 2010-06: 82.423
# no month_base input. 2010-07: 82.614
# no month_base input. 2010-08: 83.128
# no month_base input. 2010-09: 83.604
# no month_base input. 2010-10: 83.434
# no month_base input. 2010-11: 83.54
# no month_base input. 2010-12: 84.151
# no month_base input. 2010-01: 84.256
# no month_base input. 2010-02: 85.005
# no month_base input. 2010-03: 84.595
# no month_base input. 2010-04: 83.937
# no month_base input. 2010-05: 83.639
# no month_base input. 2010-06: 83.81
# no month_base input. 2010-07: 84.428
# no month_base input. 2010-08: 84.721
# no month_base input. 2010-09: 84.845
# no month_base input. 2010-10: 85.336
# no month_base input. 2010-11: 85.579
# no month_base input. 2010-12: 85.308
# no month_base input. 2010-01: 85.326
# no month_base input. 2010-02: 85.459
# no month_base input. 2010-03: 85.609
# no month_base input. 2010-04: 85.869
# no month_base input. 2010-05: 85.547
# no month_base input. 2010-06: 85.404
# no month_base input. 2010-07: 85.539
# no month_base input. 2010-08: 85.604
# no month_base input. 2010-09: 85.447
# no month_base input. 2010-10: 85.549
# no month_base input. 2010-11: 85.351
# no month_base input. 2010-12: 85.254
# no month_base input. 2010-01: 85.189
# no month_base input. 2010-02: 85.029
# no month_base input. 2010-03: 85.354
# no month_base input. 2010-04: 85.427
# no month_base input. 2010-05: 85.208
# no month_base input. 2010-06: 85.116
# no month_base input. 2010-07: 85.2
# no month_base input. 2010-08: 84.893
# no month_base input. 2010-09: 84.894
# no month_base input. 2010-10: 84.884
# no month_base input. 2010-11: 84.699
# no month_base input. 2010-12: 84.706
# no month_base input. 2010-01: 84.541
# no month_base input. 2010-02: 84.413
# no month_base input. 2010-03: 84.469
# no month_base input. 2010-04: 84.426
# no month_base input. 2010-05: 84.49
# no month_base input. 2010-06: 84.499
# no month_base input. 2010-07: 84.663
# no month_base input. 2010-08: 84.678
# no month_base input. 2010-09: 84.686
# no month_base input. 2010-10: 84.675
# no month_base input. 2010-11: 84.714
# no month_base input. 2010-12: 84.845
# no month_base input. 2010-01: 84.902
# no month_base input. 2010-02: 85.052
# no month_base input. 2010-03: 85.012
# no month_base input. 2010-04: 85.374
# no month_base input. 2010-05: 85.04
# no month_base input. 2010-06: 84.919
# no month_base input. 2010-07: 85.124
# no month_base input. 2010-08: 85.005
# no month_base input. 2010-09: 84.986
# no month_base input. 2010-10: 85.144
# no month_base input. 2010-11: 85.234
# no month_base input. 2010-12: 85.15
# no month_base input. 2010-01: 85.431
# no month_base input. 2010-02: 85.251
# no month_base input. 2010-03: 85.197
# no month_base input. 2010-04: 85.403
# no month_base input. 2010-05: 85.326
# no month_base input. 2010-06: 85.374
# no month_base input. 2010-07: 85.639
# no month_base input. 2010-08: 85.609
# no month_base input. 2010-09: 85.589
# no month_base input. 2010-10: 85.714
# no month_base input. 2010-11: 85.466
# no month_base input. 2010-12: 85.53
# no month_base input. 2010-01: 85.597
# no month_base input. 2010-02: 85.782
# no month_base input. 2010-03: 85.776
# no month_base input. 2010-04: 86.201
# no month_base input. 2010-05: 86.08
# no month_base input. 2010-06: 85.833
# no month_base input. 2010-07: 85.837
# no month_base input. 2010-08: 85.982
# no month_base input. 2010-09: 85.928
# no month_base input. 2010-10: 86.134
# no month_base input. 2010-11: 86.019
# no month_base input. 2010-12: 86.184
# no month_base input. 2010-01: 86.249
# no month_base input. 2010-02: 86.103
# no month_base input. 2010-03: 85.731
# no month_base input. 2010-04: 85.565
# no month_base input. 2010-05: 85.346
# no month_base input. 2010-06: 85.364
# no month_base input. 2010-07: 85.494
# no month_base input. 2010-08: 85.63
# no month_base input. 2010-09: 85.916
# no month_base input. 2010-10: 85.976
# no month_base input. 2010-11: 85.906
# no month_base input. 2010-12: 86.217
# no month_base input. 2010-01: 86.616
# no month_base input. 2010-02: 86.607
# no month_base input. 2010-03: 86.877
# no month_base input. 2010-04: 87.352
# no month_base input. 2010-05: 87.431
# no month_base input. 2010-06: 87.426
# no month_base input. 2010-07: 87.653
# no month_base input. 2010-08: 87.738
# no month_base input. 2010-09: 88.104
# no month_base input. 2010-10: 88.758
# no month_base input. 2010-11: 89.223
# no month_base input. 2010-12: 89.634
# no month_base input. 2010-01: 89.943
# no month_base input. 2010-02: 90.522
# no month_base input. 2010-03: 91.565
# no month_base input. 2010-04: 92.097
# no month_base input. 2010-05: 92.351
# no month_base input. 2010-06: 93.27
# no month_base input. 2010-07: 93.836
# no month_base input. 2010-08: 94.29
# no month_base input. 2010-09: 94.699
# no month_base input. 2010-10: 94.751
# no month_base input. 2010-11: 95.24
# no month_base input. 2010-12: 95.434
# no month_base input. 2010-01: 95.914
# no month_base input. 2010-02: 96.236
# no month_base input. 2010-03: 96.634
# no month_base input. 2010-04: 97.401
# no month_base input. 2010-05: 97.022
# no month_base input. 2010-06: 97.485
# no month_base input. 2010-07: 97.701
# no month_base input. 2010-08: 98.117
# no month_base input. 2010-09: 98.614
# no month_base input. 2010-10: 99.263
# no month_base input. 2010-11: 98.646
# no month_base input. 2010-12: 99.015
# no month_base input. 2010-01: 99.459
# no month_base input. 2010-02: 99.479
# no month_base input. 2010-03: 99.494
# no month_base input. 2010-04: 99.935
# no month_base input. 2010-05: 99.99
# no month_base input. 2010-06: 99.885
# no month_base input. 2010-07: 100.073
# no month_base input. 2010-08: 100.195
# no month_base input. 2010-09: 100.425
# no month_base input. 2010-10: 100.375
# no month_base input. 2010-11: 100.168
# no month_base input. 2010-12: 100.441
# no month_base input. 2010-01: 100.477
# no month_base input. 2010-02: 100.546
# no month_base input. 2010-03: 100.379
# no month_base input. 2010-04: 100.796
# no month_base input. 2010-05: 100.757
# no month_base input. 2010-06: 100.68
# no month_base input. 2010-07: 100.704
# no month_base input. 2010-08: 100.742
# no month_base input. 2010-09: 101.099
# no month_base input. 2010-10: 101.589
# no month_base input. 2010-11: 101.357
# C:\Users\user\AppData\Local\Temp\ipykernel_10592\4205628819.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_mainmetrics_sorted_earliestdate['cpi_reindexed_2010-01'] = cpi_mainmetrics_sorted_earliestdate.apply(rebase_index, axis=1, args=(cpi_mainmetrics_sorted_earliestdate.copy(), 2010, 'month', 'All Items', True, 1))
# C:\Users\user\AppData\Local\Temp\ipykernel_10592\4205628819.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_mainmetrics_sorted_earliestdate['month'] = pd.to_datetime(cpi_mainmetrics_sorted_earliestdate['month'], format='%Y-%m')

# %%
# CPI dataset
df_cpi = basicprep_cpi(cpi, 5, 4)

# COE dataset
df_coe = basicprep_coe(coe)
df_coe_a = df_coe.loc[df_coe['vehicle_class'] == 'Category A']
df_coe_b = df_coe.loc[df_coe['vehicle_class'] == 'Category B']
df_coe_d = df_coe.loc[df_coe['vehicle_class'] == 'Category D']

# Trim datasets to only the common dates so that we can plot
df_list = [df_cpi, df_coe_a, df_coe_b, df_coe_d]
common_dates = get_common_dates(df_list, 'month')
df_cpi_trim = df_cpi[df_cpi['month'].isin(common_dates)]
df_coe_a_trim = df_coe_a[df_coe_a['month'].isin(common_dates)]
df_coe_b_trim = df_coe_b[df_coe_b['month'].isin(common_dates)]
df_coe_d_trim = df_coe_d[df_coe_d['month'].isin(common_dates)]
# Out:
# no month_base input. 2010-01: 73.64
# no month_base input. 2010-02: 73.771
# no month_base input. 2010-03: 74
# no month_base input. 2010-04: 74.596
# no month_base input. 2010-05: 75.025
# no month_base input. 2010-06: 74.662
# no month_base input. 2010-07: 75.261
# no month_base input. 2010-08: 75.608
# no month_base input. 2010-09: 75.678
# no month_base input. 2010-10: 75.991
# no month_base input. 2010-11: 76.243
# no month_base input. 2010-12: 76.692
# no month_base input. 2010-01: 77.517
# no month_base input. 2010-02: 77.549
# no month_base input. 2010-03: 77.623
# no month_base input. 2010-04: 78.449
# no month_base input. 2010-05: 78.348
# no month_base input. 2010-06: 78.535
# no month_base input. 2010-07: 79.317
# no month_base input. 2010-08: 79.888
# no month_base input. 2010-09: 79.754
# no month_base input. 2010-10: 80.066
# no month_base input. 2010-11: 80.512
# no month_base input. 2010-12: 80.898
# no month_base input. 2010-01: 81.34
# no month_base input. 2010-02: 81.262
# no month_base input. 2010-03: 81.821
# no month_base input. 2010-04: 82.245
# no month_base input. 2010-05: 82.418
# no month_base input. 2010-06: 82.423
# no month_base input. 2010-07: 82.614
# no month_base input. 2010-08: 83.128
# no month_base input. 2010-09: 83.604
# no month_base input. 2010-10: 83.434
# no month_base input. 2010-11: 83.54
# no month_base input. 2010-12: 84.151
# no month_base input. 2010-01: 84.256
# no month_base input. 2010-02: 85.005
# no month_base input. 2010-03: 84.595
# no month_base input. 2010-04: 83.937
# no month_base input. 2010-05: 83.639
# no month_base input. 2010-06: 83.81
# no month_base input. 2010-07: 84.428
# no month_base input. 2010-08: 84.721
# no month_base input. 2010-09: 84.845
# no month_base input. 2010-10: 85.336
# no month_base input. 2010-11: 85.579
# no month_base input. 2010-12: 85.308
# no month_base input. 2010-01: 85.326
# no month_base input. 2010-02: 85.459
# no month_base input. 2010-03: 85.609
# no month_base input. 2010-04: 85.869
# no month_base input. 2010-05: 85.547
# no month_base input. 2010-06: 85.404
# no month_base input. 2010-07: 85.539
# no month_base input. 2010-08: 85.604
# no month_base input. 2010-09: 85.447
# no month_base input. 2010-10: 85.549
# no month_base input. 2010-11: 85.351
# no month_base input. 2010-12: 85.254
# no month_base input. 2010-01: 85.189
# no month_base input. 2010-02: 85.029
# no month_base input. 2010-03: 85.354
# no month_base input. 2010-04: 85.427
# no month_base input. 2010-05: 85.208
# no month_base input. 2010-06: 85.116
# no month_base input. 2010-07: 85.2
# no month_base input. 2010-08: 84.893
# no month_base input. 2010-09: 84.894
# no month_base input. 2010-10: 84.884
# no month_base input. 2010-11: 84.699
# no month_base input. 2010-12: 84.706
# no month_base input. 2010-01: 84.541
# no month_base input. 2010-02: 84.413
# no month_base input. 2010-03: 84.469
# no month_base input. 2010-04: 84.426
# no month_base input. 2010-05: 84.49
# no month_base input. 2010-06: 84.499
# no month_base input. 2010-07: 84.663
# no month_base input. 2010-08: 84.678
# no month_base input. 2010-09: 84.686
# no month_base input. 2010-10: 84.675
# no month_base input. 2010-11: 84.714
# no month_base input. 2010-12: 84.845
# no month_base input. 2010-01: 84.902
# no month_base input. 2010-02: 85.052
# no month_base input. 2010-03: 85.012
# no month_base input. 2010-04: 85.374
# no month_base input. 2010-05: 85.04
# no month_base input. 2010-06: 84.919
# no month_base input. 2010-07: 85.124
# no month_base input. 2010-08: 85.005
# no month_base input. 2010-09: 84.986
# no month_base input. 2010-10: 85.144
# no month_base input. 2010-11: 85.234
# no month_base input. 2010-12: 85.15
# no month_base input. 2010-01: 85.431
# no month_base input. 2010-02: 85.251
# no month_base input. 2010-03: 85.197
# no month_base input. 2010-04: 85.403
# no month_base input. 2010-05: 85.326
# no month_base input. 2010-06: 85.374
# no month_base input. 2010-07: 85.639
# no month_base input. 2010-08: 85.609
# no month_base input. 2010-09: 85.589
# no month_base input. 2010-10: 85.714
# no month_base input. 2010-11: 85.466
# no month_base input. 2010-12: 85.53
# no month_base input. 2010-01: 85.597
# no month_base input. 2010-02: 85.782
# no month_base input. 2010-03: 85.776
# no month_base input. 2010-04: 86.201
# no month_base input. 2010-05: 86.08
# no month_base input. 2010-06: 85.833
# no month_base input. 2010-07: 85.837
# no month_base input. 2010-08: 85.982
# no month_base input. 2010-09: 85.928
# no month_base input. 2010-10: 86.134
# no month_base input. 2010-11: 86.019
# no month_base input. 2010-12: 86.184
# no month_base input. 2010-01: 86.249
# no month_base input. 2010-02: 86.103
# no month_base input. 2010-03: 85.731
# no month_base input. 2010-04: 85.565
# no month_base input. 2010-05: 85.346
# no month_base input. 2010-06: 85.364
# no month_base input. 2010-07: 85.494
# no month_base input. 2010-08: 85.63
# no month_base input. 2010-09: 85.916
# no month_base input. 2010-10: 85.976
# no month_base input. 2010-11: 85.906
# no month_base input. 2010-12: 86.217
# no month_base input. 2010-01: 86.616
# no month_base input. 2010-02: 86.607
# no month_base input. 2010-03: 86.877
# no month_base input. 2010-04: 87.352
# no month_base input. 2010-05: 87.431
# no month_base input. 2010-06: 87.426
# no month_base input. 2010-07: 87.653
# no month_base input. 2010-08: 87.738
# no month_base input. 2010-09: 88.104
# no month_base input. 2010-10: 88.758
# no month_base input. 2010-11: 89.223
# no month_base input. 2010-12: 89.634
# no month_base input. 2010-01: 89.943
# no month_base input. 2010-02: 90.522
# no month_base input. 2010-03: 91.565
# no month_base input. 2010-04: 92.097
# no month_base input. 2010-05: 92.351
# no month_base input. 2010-06: 93.27
# no month_base input. 2010-07: 93.836
# no month_base input. 2010-08: 94.29
# no month_base input. 2010-09: 94.699
# no month_base input. 2010-10: 94.751
# no month_base input. 2010-11: 95.24
# no month_base input. 2010-12: 95.434
# no month_base input. 2010-01: 95.914
# no month_base input. 2010-02: 96.236
# no month_base input. 2010-03: 96.634
# no month_base input. 2010-04: 97.401
# no month_base input. 2010-05: 97.022
# no month_base input. 2010-06: 97.485
# no month_base input. 2010-07: 97.701
# no month_base input. 2010-08: 98.117
# no month_base input. 2010-09: 98.614
# no month_base input. 2010-10: 99.263
# no month_base input. 2010-11: 98.646
# no month_base input. 2010-12: 99.015
# no month_base input. 2010-01: 99.459
# no month_base input. 2010-02: 99.479
# no month_base input. 2010-03: 99.494
# no month_base input. 2010-04: 99.935
# no month_base input. 2010-05: 99.99
# no month_base input. 2010-06: 99.885
# no month_base input. 2010-07: 100.073
# no month_base input. 2010-08: 100.195
# no month_base input. 2010-09: 100.425
# no month_base input. 2010-10: 100.375
# no month_base input. 2010-11: 100.168
# no month_base input. 2010-12: 100.441
# no month_base input. 2010-01: 100.477
# no month_base input. 2010-02: 100.546
# no month_base input. 2010-03: 100.379
# no month_base input. 2010-04: 100.796
# no month_base input. 2010-05: 100.757
# no month_base input. 2010-06: 100.68
# no month_base input. 2010-07: 100.704
# no month_base input. 2010-08: 100.742
# no month_base input. 2010-09: 101.099
# no month_base input. 2010-10: 101.589
# no month_base input. 2010-11: 101.357
# C:\Users\user\AppData\Local\Temp\ipykernel_10592\4205628819.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_mainmetrics_sorted_earliestdate['cpi_reindexed_2010-01'] = cpi_mainmetrics_sorted_earliestdate.apply(rebase_index, axis=1, args=(cpi_mainmetrics_sorted_earliestdate.copy(), 2010, 'month', 'All Items', True, 1))
# C:\Users\user\AppData\Local\Temp\ipykernel_10592\4205628819.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_mainmetrics_sorted_earliestdate['month'] = pd.to_datetime(cpi_mainmetrics_sorted_earliestdate['month'], format='%Y-%m')
# no month_base input. 2010-01: 19501.5
# no month_base input. 2010-01: 20795.0
# no month_base input. 2010-01: 19545.5
# no month_base input. 2010-01: 870.5
# no month_base input. 2010-01: 20894.0
# no month_base input. 2010-02: 20164.5
# no month_base input. 2010-02: 23534.5
# no month_base input. 2010-02: 22445.5
# no month_base input. 2010-02: 926.5
# no month_base input. 2010-02: 23315.0
# no month_base input. 2010-03: 24595.5
# no month_base input. 2010-03: 31239.0
# no month_base input. 2010-03: 29945.5
# no month_base input. 2010-03: 1179.5
# no month_base input. 2010-03: 34795.5
# no month_base input. 2010-04: 32000.5
# no month_base input. 2010-04: 42751.0
# no month_base input. 2010-04: 36033.5
# no month_base input. 2010-04: 1237.0
# no month_base input. 2010-04: 46001.5
# no month_base input. 2010-05: 26745.5
# no month_base input. 2010-05: 36300.0
# no month_base input. 2010-05: 30945.0
# no month_base input. 2010-05: 1282.0
# no month_base input. 2010-05: 39001.0
# no month_base input. 2010-06: 30780.5
# no month_base input. 2010-06: 39956.5
# no month_base input. 2010-06: 30939.0
# no month_base input. 2010-06: 1453.0
# no month_base input. 2010-06: 41003.0
# no month_base input. 2010-07: 32831.5
# no month_base input. 2010-07: 39399.0
# no month_base input. 2010-07: 30995.0
# no month_base input. 2010-07: 1305.0
# no month_base input. 2010-07: 42287.5
# no month_base input. 2010-08: 30552.0
# no month_base input. 2010-08: 43072.0
# no month_base input. 2010-08: 30057.0
# no month_base input. 2010-08: 1276.0
# no month_base input. 2010-08: 43201.0
# no month_base input. 2010-09: 31545.0
# no month_base input. 2010-09: 43315.0
# no month_base input. 2010-09: 32000.5
# no month_base input. 2010-09: 1477.0
# no month_base input. 2010-09: 43645.5
# no month_base input. 2010-10: 32773.5
# no month_base input. 2010-10: 43700.5
# no month_base input. 2010-10: 30700.0
# no month_base input. 2010-10: 1595.5
# no month_base input. 2010-10: 44495.0
# no month_base input. 2010-11: 36500.5
# no month_base input. 2010-11: 46695.5
# no month_base input. 2010-11: 31104.0
# no month_base input. 2010-11: 1477.0
# no month_base input. 2010-11: 47945.5
# no month_base input. 2010-12: 46866.5
# no month_base input. 2010-12: 67251.5
# no month_base input. 2010-12: 32751.0
# no month_base input. 2010-12: 1626.0
# no month_base input. 2010-12: 70501.0
# no month_base input. 2010-01: 39506.0
# no month_base input. 2010-01: 63955.0
# no month_base input. 2010-01: 32555.5
# no month_base input. 2010-01: 1596.5
# no month_base input. 2010-01: 71399.0
# no month_base input. 2010-02: 40061.5
# no month_base input. 2010-02: 57700.0
# no month_base input. 2010-02: 28800.0
# no month_base input. 2010-02: 1910.0
# no month_base input. 2010-02: 60445.5
# no month_base input. 2010-03: 43206.5
# no month_base input. 2010-03: 59448.0
# no month_base input. 2010-03: 29845.5
# no month_base input. 2010-03: 2569.0
# no month_base input. 2010-03: 60541.5
# no month_base input. 2010-04: 43606.0
# no month_base input. 2010-04: 55901.0
# no month_base input. 2010-04: 26044.5
# no month_base input. 2010-04: 2496.0
# no month_base input. 2010-04: 56550.5
# no month_base input. 2010-05: 45889.5
# no month_base input. 2010-05: 56155.5
# no month_base input. 2010-05: 22439.0
# no month_base input. 2010-05: 2133.0
# no month_base input. 2010-05: 56689.5
# no month_base input. 2010-06: 51817.0
# no month_base input. 2010-06: 65350.0
# no month_base input. 2010-06: 30047.5
# no month_base input. 2010-06: 2390.5
# no month_base input. 2010-06: 63745.0
# no month_base input. 2010-07: 55995.5
# no month_base input. 2010-07: 70501.0
# no month_base input. 2010-07: 33546.0
# no month_base input. 2010-07: 2186.0
# no month_base input. 2010-07: 71650.5
# no month_base input. 2010-08: 49051.0
# no month_base input. 2010-08: 68205.5
# no month_base input. 2010-08: 33149.0
# no month_base input. 2010-08: 1944.5
# no month_base input. 2010-08: 68558.5
# no month_base input. 2010-09: 49503.0
# no month_base input. 2010-09: 63945.5
# no month_base input. 2010-09: 30994.5
# no month_base input. 2010-09: 2224.0
# no month_base input. 2010-09: 64045.5
# no month_base input. 2010-10: 53200.5
# no month_base input. 2010-10: 69744.5
# no month_base input. 2010-10: 34906.0
# no month_base input. 2010-10: 2084.5
# no month_base input. 2010-10: 69329.0
# no month_base input. 2010-11: 55442.0
# no month_base input. 2010-11: 77170.0
# no month_base input. 2010-11: 40496.0
# no month_base input. 2010-11: 1950.5
# no month_base input. 2010-11: 76945.0
# no month_base input. 2010-12: 51196.5
# no month_base input. 2010-12: 71176.5
# no month_base input. 2010-12: 39799.0
# no month_base input. 2010-12: 1691.5
# no month_base input. 2010-12: 72670.0
# no month_base input. 2010-01: 47500.5
# no month_base input. 2010-01: 66845.0
# no month_base input. 2010-01: 41350.0
# no month_base input. 2010-01: 1617.0
# no month_base input. 2010-01: 66400.5
# no month_base input. 2010-02: 54909.0
# no month_base input. 2010-02: 76039.5
# no month_base input. 2010-02: 50902.5
# no month_base input. 2010-02: 1907.0
# no month_base input. 2010-02: 75900.5
# no month_base input. 2010-03: 56526.0
# no month_base input. 2010-03: 80653.5
# no month_base input. 2010-03: 50760.0
# no month_base input. 2010-03: 1745.0
# no month_base input. 2010-03: 78491.0
# no month_base input. 2010-04: 61351.0
# no month_base input. 2010-04: 87350.0
# no month_base input. 2010-04: 55789.0
# no month_base input. 2010-04: 1910.0
# no month_base input. 2010-04: 88300.0
# no month_base input. 2010-05: 60300.5
# no month_base input. 2010-05: 88633.0
# no month_base input. 2010-05: 57829.5
# no month_base input. 2010-05: 1955.5
# no month_base input. 2010-05: 87939.5
# no month_base input. 2010-06: 59003.5
# no month_base input. 2010-06: 84200.0
# no month_base input. 2010-06: 54512.0
# no month_base input. 2010-06: 1812.0
# no month_base input. 2010-06: 85139.0
# no month_base input. 2010-07: 64038.5
# no month_base input. 2010-07: 86395.0
# no month_base input. 2010-07: 55680.5
# no month_base input. 2010-07: 1809.5
# no month_base input. 2010-07: 89849.5
# no month_base input. 2010-08: 70195.0
# no month_base input. 2010-08: 91252.0
# no month_base input. 2010-08: 58167.5
# no month_base input. 2010-08: 2047.0
# no month_base input. 2010-08: 94512.0
# no month_base input. 2010-09: 65500.0
# no month_base input. 2010-09: 84345.5
# no month_base input. 2010-09: 57571.5
# no month_base input. 2010-09: 1826.5
# no month_base input. 2010-09: 88994.5
# no month_base input. 2010-10: 70000.5
# no month_base input. 2010-10: 82901.0
# no month_base input. 2010-10: 56945.0
# no month_base input. 2010-10: 1916.0
# no month_base input. 2010-10: 86944.5
# no month_base input. 2010-11: 77246.0
# no month_base input. 2010-11: 92702.0
# no month_base input. 2010-11: 59673.0
# no month_base input. 2010-11: 1824.0
# no month_base input. 2010-11: 93045.0
# no month_base input. 2010-12: 80206.0
# no month_base input. 2010-12: 91850.5
# no month_base input. 2010-12: 62618.0
# no month_base input. 2010-12: 1656.5
# no month_base input. 2010-12: 96495.0
# no month_base input. 2010-01: 91555.0
# no month_base input. 2010-01: 95855.5
# no month_base input. 2010-01: 58525.5
# no month_base input. 2010-01: 1857.0
# no month_base input. 2010-01: 96995.0
# no month_base input. 2010-02: 82705.0
# no month_base input. 2010-02: 92784.0
# no month_base input. 2010-02: 54239.0
# no month_base input. 2010-02: 1647.0
# no month_base input. 2010-02: 93400.0
# no month_base input. 2010-03: 69449.0
# no month_base input. 2010-03: 65995.0
# no month_base input. 2010-03: 54005.5
# no month_base input. 2010-03: 1902.0
# no month_base input. 2010-03: 69151.0
# no month_base input. 2010-04: 61763.0
# no month_base input. 2010-04: 64505.0
# no month_base input. 2010-04: 57256.5
# no month_base input. 2010-04: 1801.5
# no month_base input. 2010-04: 64494.5
# no month_base input. 2010-05: 63919.0
# no month_base input. 2010-05: 64502.0
# no month_base input. 2010-05: 56970.0
# no month_base input. 2010-05: 1681.5
# no month_base input. 2010-05: 64501.0
# no month_base input. 2010-06: 68602.0
# no month_base input. 2010-06: 78375.5
# no month_base input. 2010-06: 58495.0
# no month_base input. 2010-06: 1706.5
# no month_base input. 2010-06: 79500.5
# no month_base input. 2010-07: 73544.5
# no month_base input. 2010-07: 76749.5
# no month_base input. 2010-07: 63023.5
# no month_base input. 2010-07: 1661.0
# no month_base input. 2010-07: 76901.0
# no month_base input. 2010-08: 75889.5
# no month_base input. 2010-08: 77103.5
# no month_base input. 2010-08: 69626.0
# no month_base input. 2010-08: 1757.0
# no month_base input. 2010-08: 78606.0
# no month_base input. 2010-09: 80527.5
# no month_base input. 2010-09: 81669.5
# no month_base input. 2010-09: 75000.0
# no month_base input. 2010-09: 1681.5
# no month_base input. 2010-09: 83500.5
# no month_base input. 2010-10: 80944.5
# no month_base input. 2010-10: 90705.0
# no month_base input. 2010-10: 72156.0
# no month_base input. 2010-10: 1882.5
# no month_base input. 2010-10: 93089.0
# no month_base input. 2010-11: 73800.0
# no month_base input. 2010-11: 81939.0
# no month_base input. 2010-11: 55252.5
# no month_base input. 2010-11: 1711.0
# no month_base input. 2010-11: 86000.5
# no month_base input. 2010-12: 73581.0
# no month_base input. 2010-12: 74355.0
# no month_base input. 2010-12: 49556.5
# no month_base input. 2010-12: 1797.0
# no month_base input. 2010-12: 77201.0
# no month_base input. 2010-01: 72329.5
# no month_base input. 2010-01: 78850.0
# no month_base input. 2010-01: 49445.0
# no month_base input. 2010-01: 2346.5
# no month_base input. 2010-01: 78905.0
# no month_base input. 2010-02: 74382.5
# no month_base input. 2010-02: 76952.0
# no month_base input. 2010-02: 51946.0
# no month_base input. 2010-02: 3276.0
# no month_base input. 2010-02: 78001.5
# no month_base input. 2010-03: 77800.5
# no month_base input. 2010-03: 81805.0
# no month_base input. 2010-03: 55096.5
# no month_base input. 2010-03: 4145.0
# no month_base input. 2010-03: 83000.5
# no month_base input. 2010-04: 74367.5
# no month_base input. 2010-04: 79757.0
# no month_base input. 2010-04: 41196.5
# no month_base input. 2010-04: 4495.5
# no month_base input. 2010-04: 78955.0
# no month_base input. 2010-05: 62845.5
# no month_base input. 2010-05: 69052.5
# no month_base input. 2010-05: 38595.0
# no month_base input. 2010-05: 4002.0
# no month_base input. 2010-05: 66395.5
# no month_base input. 2010-06: 62544.5
# no month_base input. 2010-06: 66502.0
# no month_base input. 2010-06: 42501.0
# no month_base input. 2010-06: 3989.5
# no month_base input. 2010-06: 66317.5
# no month_base input. 2010-07: 62440.0
# no month_base input. 2010-07: 64945.0
# no month_base input. 2010-07: 47700.0
# no month_base input. 2010-07: 4126.5
# no month_base input. 2010-07: 64001.5
# no month_base input. 2010-08: 65155.0
# no month_base input. 2010-08: 70839.5
# no month_base input. 2010-08: 53199.5
# no month_base input. 2010-08: 4353.5
# no month_base input. 2010-08: 70905.5
# no month_base input. 2010-09: 63420.5
# no month_base input. 2010-09: 72500.0
# no month_base input. 2010-09: 49895.0
# no month_base input. 2010-09: 4478.5
# no month_base input. 2010-09: 74602.0
# no month_base input. 2010-10: 63935.0
# no month_base input. 2010-10: 72091.0
# no month_base input. 2010-10: 59194.5
# no month_base input. 2010-10: 4606.0
# no month_base input. 2010-10: 72102.0
# no month_base input. 2010-11: 66394.5
# no month_base input. 2010-11: 71890.0
# no month_base input. 2010-11: 64351.0
# no month_base input. 2010-11: 4239.5
# no month_base input. 2010-11: 72600.0
# no month_base input. 2010-12: 66489.0
# no month_base input. 2010-12: 74194.5
# no month_base input. 2010-12: 56050.5
# no month_base input. 2010-12: 4261.0
# no month_base input. 2010-12: 75447.0
# no month_base input. 2010-01: 65505.5
# no month_base input. 2010-01: 76089.0
# no month_base input. 2010-01: 55011.5
# no month_base input. 2010-01: 4646.0
# no month_base input. 2010-01: 75995.0
# no month_base input. 2010-02: 59600.5
# no month_base input. 2010-02: 68820.5
# no month_base input. 2010-02: 52651.5
# no month_base input. 2010-02: 5652.0
# no month_base input. 2010-02: 69911.0
# no month_base input. 2010-03: 63055.0
# no month_base input. 2010-03: 70278.5
# no month_base input. 2010-03: 58250.0
# no month_base input. 2010-03: 5555.5
# no month_base input. 2010-03: 71300.0
# no month_base input. 2010-04: 67675.0
# no month_base input. 2010-04: 77306.5
# no month_base input. 2010-04: 58501.0
# no month_base input. 2010-04: 6556.5
# no month_base input. 2010-04: 78750.0
# no month_base input. 2010-05: 67589.5
# no month_base input. 2010-05: 76301.0
# no month_base input. 2010-05: 51049.5
# no month_base input. 2010-05: 6506.5
# no month_base input. 2010-05: 78002.5
# no month_base input. 2010-06: 63500.0
# no month_base input. 2010-06: 73254.5
# no month_base input. 2010-06: 50701.0
# no month_base input. 2010-06: 6455.0
# no month_base input. 2010-06: 75151.0
# no month_base input. 2010-07: 57294.5
# no month_base input. 2010-07: 61805.0
# no month_base input. 2010-07: 50001.5
# no month_base input. 2010-07: 6410.0
# no month_base input. 2010-07: 64551.0
# no month_base input. 2010-08: 56853.5
# no month_base input. 2010-08: 61464.5
# no month_base input. 2010-08: 47901.5
# no month_base input. 2010-08: 6156.5
# no month_base input. 2010-08: 59443.0
# no month_base input. 2010-09: 56244.0
# no month_base input. 2010-09: 61051.0
# no month_base input. 2010-09: 46045.0
# no month_base input. 2010-09: 6335.0
# no month_base input. 2010-09: 61155.0
# no month_base input. 2010-10: 56651.0
# no month_base input. 2010-10: 59039.5
# no month_base input. 2010-10: 43596.5
# no month_base input. 2010-10: 6251.5
# no month_base input. 2010-10: 59400.5
# no month_base input. 2010-11: 57600.5
# no month_base input. 2010-11: 59302.0
# no month_base input. 2010-11: 44849.5
# no month_base input. 2010-11: 6207.0
# no month_base input. 2010-11: 61354.0
# no month_base input. 2010-12: 55645.0
# no month_base input. 2010-12: 57501.0
# no month_base input. 2010-12: 47051.0
# no month_base input. 2010-12: 6550.5
# no month_base input. 2010-12: 58752.0
# no month_base input. 2010-01: 48151.5
# no month_base input. 2010-01: 52504.5
# no month_base input. 2010-01: 44269.0
# no month_base input. 2010-01: 6700.5
# no month_base input. 2010-01: 53044.5
# no month_base input. 2010-02: 44825.5
# no month_base input. 2010-02: 42790.0
# no month_base input. 2010-02: 45018.5
# no month_base input. 2010-02: 6428.0
# no month_base input. 2010-02: 44505.0
# no month_base input. 2010-03: 45252.0
# no month_base input. 2010-03: 47053.0
# no month_base input. 2010-03: 47696.0
# no month_base input. 2010-03: 6546.0
# no month_base input. 2010-03: 47334.5
# no month_base input. 2010-04: 46654.5
# no month_base input. 2010-04: 48301.0
# no month_base input. 2010-04: 43607.5
# no month_base input. 2010-04: 6502.0
# no month_base input. 2010-04: 48505.5
# no month_base input. 2010-05: 47454.5
# no month_base input. 2010-05: 50083.0
# no month_base input. 2010-05: 42652.0
# no month_base input. 2010-05: 6302.5
# no month_base input. 2010-05: 49350.0
# no month_base input. 2010-06: 54447.0
# no month_base input. 2010-06: 56505.0
# no month_base input. 2010-06: 47218.0
# no month_base input. 2010-06: 6302.5
# no month_base input. 2010-06: 56245.0
# no month_base input. 2010-07: 52650.5
# no month_base input. 2010-07: 56798.5
# no month_base input. 2010-07: 48889.5
# no month_base input. 2010-07: 6157.0
# no month_base input. 2010-07: 56751.5
# no month_base input. 2010-08: 52918.5
# no month_base input. 2010-08: 57201.5
# no month_base input. 2010-08: 48151.5
# no month_base input. 2010-08: 6279.0
# no month_base input. 2010-08: 57578.5
# no month_base input. 2010-09: 50753.0
# no month_base input. 2010-09: 56251.5
# no month_base input. 2010-09: 49845.5
# no month_base input. 2010-09: 6476.5
# no month_base input. 2010-09: 56045.0
# no month_base input. 2010-10: 51249.0
# no month_base input. 2010-10: 54705.5
# no month_base input. 2010-10: 47145.5
# no month_base input. 2010-10: 6353.5
# no month_base input. 2010-10: 55270.0
# no month_base input. 2010-11: 51809.5
# no month_base input. 2010-11: 54603.5
# no month_base input. 2010-11: 48501.5
# no month_base input. 2010-11: 6261.5
# no month_base input. 2010-11: 55450.5
# no month_base input. 2010-12: 48875.5
# no month_base input. 2010-12: 48669.0
# no month_base input. 2010-12: 50354.5
# no month_base input. 2010-12: 6107.0
# no month_base input. 2010-12: 50199.5
# no month_base input. 2010-01: 50495.0
# no month_base input. 2010-01: 52956.5
# no month_base input. 2010-01: 46651.5
# no month_base input. 2010-01: 6052.5
# no month_base input. 2010-01: 52800.5
# no month_base input. 2010-02: 48915.5
# no month_base input. 2010-02: 49415.0
# no month_base input. 2010-02: 49355.5
# no month_base input. 2010-02: 6606.5
# no month_base input. 2010-02: 49778.0
# no month_base input. 2010-03: 51277.0
# no month_base input. 2010-03: 53650.0
# no month_base input. 2010-03: 48019.0
# no month_base input. 2010-03: 7782.0
# no month_base input. 2010-03: 53751.0
# no month_base input. 2010-04: 51800.0
# no month_base input. 2010-04: 54405.5
# no month_base input. 2010-04: 36203.5
# no month_base input. 2010-04: 7150.5
# no month_base input. 2010-04: 54586.0
# no month_base input. 2010-05: 48797.5
# no month_base input. 2010-05: 54207.5
# no month_base input. 2010-05: 28314.5
# no month_base input. 2010-05: 6201.0
# no month_base input. 2010-05: 53500.0
# no month_base input. 2010-06: 44001.0
# no month_base input. 2010-06: 48805.5
# no month_base input. 2010-06: 37690.0
# no month_base input. 2010-06: 6051.0
# no month_base input. 2010-06: 49263.5
# no month_base input. 2010-07: 43401.5
# no month_base input. 2010-07: 49901.5
# no month_base input. 2010-07: 41510.5
# no month_base input. 2010-07: 5926.0
# no month_base input. 2010-07: 50000.0
# no month_base input. 2010-08: 44839.0
# no month_base input. 2010-08: 52355.5
# no month_base input. 2010-08: 42402.5
# no month_base input. 2010-08: 4606.5
# no month_base input. 2010-08: 51375.5
# no month_base input. 2010-09: 39451.5
# no month_base input. 2010-09: 49094.5
# no month_base input. 2010-09: 44946.0
# no month_base input. 2010-09: 5451.5
# no month_base input. 2010-09: 48508.5
# no month_base input. 2010-10: 41689.0
# no month_base input. 2010-10: 49052.5
# no month_base input. 2010-10: 50396.0
# no month_base input. 2010-10: 4956.5
# no month_base input. 2010-10: 50500.0
# no month_base input. 2010-11: 46951.5
# no month_base input. 2010-11: 57402.0
# no month_base input. 2010-11: 57868.5
# no month_base input. 2010-11: 5747.0
# no month_base input. 2010-11: 57250.5
# no month_base input. 2010-12: 40269.5
# no month_base input. 2010-12: 50356.5
# no month_base input. 2010-12: 43556.0
# no month_base input. 2010-12: 7026.5
# no month_base input. 2010-12: 51172.5
# no month_base input. 2010-01: 39145.0
# no month_base input. 2010-01: 43975.0
# no month_base input. 2010-01: 39550.5
# no month_base input. 2010-01: 7851.0
# no month_base input. 2010-01: 45695.0
# no month_base input. 2010-02: 38405.0
# no month_base input. 2010-02: 40661.0
# no month_base input. 2010-02: 37581.0
# no month_base input. 2010-02: 8059.0
# no month_base input. 2010-02: 39352.0
# no month_base input. 2010-03: 38415.0
# no month_base input. 2010-03: 38005.5
# no month_base input. 2010-03: 35502.0
# no month_base input. 2010-03: 7805.5
# no month_base input. 2010-03: 38500.0
# no month_base input. 2010-04: 37755.0
# no month_base input. 2010-04: 37467.5
# no month_base input. 2010-04: 34101.5
# no month_base input. 2010-04: 7114.5
# no month_base input. 2010-04: 38214.0
# no month_base input. 2010-05: 38471.0
# no month_base input. 2010-05: 38245.0
# no month_base input. 2010-05: 31545.5
# no month_base input. 2010-05: 7159.5
# no month_base input. 2010-05: 38650.0
# no month_base input. 2010-06: 35268.0
# no month_base input. 2010-06: 34950.0
# no month_base input. 2010-06: 30951.5
# no month_base input. 2010-06: 6945.0
# no month_base input. 2010-06: 35700.0
# no month_base input. 2010-07: 28849.5
# no month_base input. 2010-07: 31775.5
# no month_base input. 2010-07: 30990.5
# no month_base input. 2010-07: 6351.5
# no month_base input. 2010-07: 31905.0
# no month_base input. 2010-08: 32897.5
# no month_base input. 2010-08: 33405.0
# no month_base input. 2010-08: 30145.5
# no month_base input. 2010-08: 5201.5
# no month_base input. 2010-08: 32865.5
# no month_base input. 2010-09: 29104.5
# no month_base input. 2010-09: 31654.0
# no month_base input. 2010-09: 27052.5
# no month_base input. 2010-09: 4302.0
# no month_base input. 2010-09: 31900.5
# no month_base input. 2010-10: 27006.5
# no month_base input. 2010-10: 31301.5
# no month_base input. 2010-10: 29001.0
# no month_base input. 2010-10: 4030.0
# no month_base input. 2010-10: 32726.0
# no month_base input. 2010-11: 26599.5
# no month_base input. 2010-11: 31701.5
# no month_base input. 2010-11: 28505.0
# no month_base input. 2010-11: 2749.0
# no month_base input. 2010-11: 31479.5
# no month_base input. 2010-12: 24534.5
# no month_base input. 2010-12: 31001.0
# no month_base input. 2010-12: 27005.0
# no month_base input. 2010-12: 3594.0
# no month_base input. 2010-12: 31330.0
# no month_base input. 2010-01: 26045.0
# no month_base input. 2010-01: 33094.5
# no month_base input. 2010-01: 26616.0
# no month_base input. 2010-01: 3249.5
# no month_base input. 2010-01: 33299.0
# no month_base input. 2010-02: 25995.0
# no month_base input. 2010-02: 34956.0
# no month_base input. 2010-02: 26646.0
# no month_base input. 2010-02: 3699.0
# no month_base input. 2010-02: 35988.5
# no month_base input. 2010-03: 26484.0
# no month_base input. 2010-03: 38181.0
# no month_base input. 2010-03: 27015.5
# no month_base input. 2010-03: 3535.5
# no month_base input. 2010-03: 39310.0
# no month_base input. 2010-04: 31179.0
# no month_base input. 2010-04: 45551.0
# no month_base input. 2010-04: 29795.0
# no month_base input. 2010-04: 3476.5
# no month_base input. 2010-04: 50309.5
# no month_base input. 2010-05: 31852.0
# no month_base input. 2010-05: 45287.0
# no month_base input. 2010-05: 27979.5
# no month_base input. 2010-05: 3277.0
# no month_base input. 2010-05: 49751.0
# no month_base input. 2010-06: 28504.0
# no month_base input. 2010-06: 37817.0
# no month_base input. 2010-06: 25501.5
# no month_base input. 2010-06: 3045.0
# no month_base input. 2010-06: 40701.0
# no month_base input. 2010-07: 27628.0
# no month_base input. 2010-07: 36703.0
# no month_base input. 2010-07: 24844.0
# no month_base input. 2010-07: 3317.5
# no month_base input. 2010-07: 38395.0
# no month_base input. 2010-08: 32321.0
# no month_base input. 2010-08: 39301.5
# no month_base input. 2010-08: 27150.5
# no month_base input. 2010-08: 4350.5
# no month_base input. 2010-08: 40257.0
# no month_base input. 2010-09: 31771.0
# no month_base input. 2010-09: 36500.5
# no month_base input. 2010-09: 25529.0
# no month_base input. 2010-09: 3845.0
# no month_base input. 2010-09: 38956.0
# no month_base input. 2010-10: 33155.0
# no month_base input. 2010-10: 41583.0
# no month_base input. 2010-10: 26255.0
# no month_base input. 2010-10: 3844.5
# no month_base input. 2010-10: 41510.5
# no month_base input. 2010-11: 31000.0
# no month_base input. 2010-11: 39854.5
# no month_base input. 2010-11: 24947.0
# no month_base input. 2010-11: 4010.5
# no month_base input. 2010-11: 40495.0
# no month_base input. 2010-12: 32949.0
# no month_base input. 2010-12: 36950.0
# no month_base input. 2010-12: 23452.0
# no month_base input. 2010-12: 3723.5
# no month_base input. 2010-12: 38439.0
# no month_base input. 2010-01: 35165.0
# no month_base input. 2010-01: 37407.0
# no month_base input. 2010-01: 24701.5
# no month_base input. 2010-01: 4299.5
# no month_base input. 2010-01: 37750.0
# no month_base input. 2010-02: 31504.5
# no month_base input. 2010-02: 31889.5
# no month_base input. 2010-02: 25007.0
# no month_base input. 2010-02: 4355.0
# no month_base input. 2010-02: 34100.5
# no month_base input. 2010-03: 31954.5
# no month_base input. 2010-03: 31406.5
# no month_base input. 2010-03: 23102.0
# no month_base input. 2010-03: 4399.5
# no month_base input. 2010-03: 32500.0
# no month_base input. 2010-07: 33109.5
# no month_base input. 2010-07: 35445.0
# no month_base input. 2010-07: 24195.0
# no month_base input. 2010-07: 7106.0
# no month_base input. 2010-07: 34995.0
# no month_base input. 2010-08: 34355.0
# no month_base input. 2010-08: 37952.0
# no month_base input. 2010-08: 24553.0
# no month_base input. 2010-08: 7566.5
# no month_base input. 2010-08: 37306.0
# no month_base input. 2010-09: 38135.0
# no month_base input. 2010-09: 41249.5
# no month_base input. 2010-09: 27616.5
# no month_base input. 2010-09: 7365.0
# no month_base input. 2010-09: 40895.5
# no month_base input. 2010-10: 36934.0
# no month_base input. 2010-10: 40840.0
# no month_base input. 2010-10: 33433.5
# no month_base input. 2010-10: 7375.5
# no month_base input. 2010-10: 40095.0
# no month_base input. 2010-11: 36840.0
# no month_base input. 2010-11: 40050.5
# no month_base input. 2010-11: 30918.0
# no month_base input. 2010-11: 7275.5
# no month_base input. 2010-11: 40501.5
# no month_base input. 2010-12: 40635.0
# no month_base input. 2010-12: 47156.0
# no month_base input. 2010-12: 34045.0
# no month_base input. 2010-12: 7679.5
# no month_base input. 2010-12: 47505.0
# no month_base input. 2010-01: 42055.0
# no month_base input. 2010-01: 49550.5
# no month_base input. 2010-01: 38449.5
# no month_base input. 2010-01: 7545.0
# no month_base input. 2010-01: 50694.5
# no month_base input. 2010-02: 41500.5
# no month_base input. 2010-02: 46396.0
# no month_base input. 2010-02: 42945.5
# no month_base input. 2010-02: 7503.0
# no month_base input. 2010-02: 48642.0
# no month_base input. 2010-03: 43292.5
# no month_base input. 2010-03: 46001.0
# no month_base input. 2010-03: 38551.0
# no month_base input. 2010-03: 7771.5
# no month_base input. 2010-03: 47403.5
# no month_base input. 2010-04: 47620.0
# no month_base input. 2010-04: 56749.5
# no month_base input. 2010-04: 40067.5
# no month_base input. 2010-04: 8000.0
# no month_base input. 2010-04: 57150.0
# no month_base input. 2010-05: 44901.5
# no month_base input. 2010-05: 59045.0
# no month_base input. 2010-05: 42351.0
# no month_base input. 2010-05: 8356.0
# no month_base input. 2010-05: 62501.0
# no month_base input. 2010-06: 48165.5
# no month_base input. 2010-06: 58070.5
# no month_base input. 2010-06: 37001.0
# no month_base input. 2010-06: 8602.0
# no month_base input. 2010-06: 59556.5
# no month_base input. 2010-07: 46005.5
# no month_base input. 2010-07: 57800.5
# no month_base input. 2010-07: 39211.5
# no month_base input. 2010-07: 8595.5
# no month_base input. 2010-07: 58850.5
# no month_base input. 2010-08: 45939.0
# no month_base input. 2010-08: 58501.0
# no month_base input. 2010-08: 41299.5
# no month_base input. 2010-08: 9199.5
# no month_base input. 2010-08: 62250.0
# no month_base input. 2010-09: 47500.0
# no month_base input. 2010-09: 65455.0
# no month_base input. 2010-09: 39500.5
# no month_base input. 2010-09: 9389.0
# no month_base input. 2010-09: 67351.0
# no month_base input. 2010-10: 49855.0
# no month_base input. 2010-10: 75205.0
# no month_base input. 2010-10: 39695.5
# no month_base input. 2010-10: 9181.0
# no month_base input. 2010-10: 78878.0
# no month_base input. 2010-11: 54355.0
# no month_base input. 2010-11: 81201.0
# no month_base input. 2010-11: 42751.5
# no month_base input. 2010-11: 9381.0
# no month_base input. 2010-11: 87000.5
# no month_base input. 2010-12: 57905.5
# no month_base input. 2010-12: 80695.0
# no month_base input. 2010-12: 44500.0
# no month_base input. 2010-12: 9501.0
# no month_base input. 2010-12: 84444.5
# no month_base input. 2010-01: 57748.5
# no month_base input. 2010-01: 79850.5
# no month_base input. 2010-01: 42600.5
# no month_base input. 2010-01: 9844.5
# no month_base input. 2010-01: 83206.0
# no month_base input. 2010-02: 61880.5
# no month_base input. 2010-02: 89846.0
# no month_base input. 2010-02: 45251.0
# no month_base input. 2010-02: 10299.5
# no month_base input. 2010-02: 90051.0
# no month_base input. 2010-03: 70028.5
# no month_base input. 2010-03: 96889.0
# no month_base input. 2010-03: 50196.5
# no month_base input. 2010-03: 10950.5
# no month_base input. 2010-03: 98950.0
# no month_base input. 2010-04: 70847.5
# no month_base input. 2010-04: 94195.5
# no month_base input. 2010-04: 53451.5
# no month_base input. 2010-04: 10152.0
# no month_base input. 2010-04: 97900.0
# no month_base input. 2010-05: 69451.0
# no month_base input. 2010-05: 93989.5
# no month_base input. 2010-05: 51195.5
# no month_base input. 2010-05: 9489.5
# no month_base input. 2010-05: 93506.5
# no month_base input. 2010-06: 74395.0
# no month_base input. 2010-06: 103342.5
# no month_base input. 2010-06: 53006.5
# no month_base input. 2010-06: 10151.0
# no month_base input. 2010-06: 102548.5
# no month_base input. 2010-07: 78450.0
# no month_base input. 2010-07: 108901.5
# no month_base input. 2010-07: 54445.0
# no month_base input. 2010-07: 10899.5
# no month_base input. 2010-07: 112262.5
# no month_base input. 2010-08: 83944.5
# no month_base input. 2010-08: 109501.0
# no month_base input. 2010-08: 57589.5
# no month_base input. 2010-08: 11050.5
# no month_base input. 2010-08: 112500.5
# no month_base input. 2010-09: 85000.0
# no month_base input. 2010-09: 110525.5
# no month_base input. 2010-09: 65995.0
# no month_base input. 2010-09: 11445.0
# no month_base input. 2010-09: 110250.0
# no month_base input. 2010-10: 80795.0
# no month_base input. 2010-10: 102928.0
# no month_base input. 2010-10: 68096.0
# no month_base input. 2010-10: 12276.0
# no month_base input. 2010-10: 106502.0
# no month_base input. 2010-11: 88912.0
# no month_base input. 2010-11: 114634.5
# no month_base input. 2010-11: 79052.0
# no month_base input. 2010-11: 12889.0
# no month_base input. 2010-11: 115293.0
# no month_base input. 2010-12: 88255.0
# no month_base input. 2010-12: 106753.5
# no month_base input. 2010-12: 79850.5
# no month_base input. 2010-12: 11895.0
# no month_base input. 2010-12: 110062.0
# no month_base input. 2010-01: 83000.0
# no month_base input. 2010-01: 103730.5
# no month_base input. 2010-01: 77205.0
# no month_base input. 2010-01: 10995.5
# no month_base input. 2010-01: 107444.5
# no month_base input. 2010-02: 86278.0
# no month_base input. 2010-02: 110262.5
# no month_base input. 2010-02: 86454.5
# no month_base input. 2010-02: 11895.5
# no month_base input. 2010-02: 111501.5
# no month_base input. 2010-03: 90751.5
# no month_base input. 2010-03: 115851.0
# no month_base input. 2010-03: 88245.0
# no month_base input. 2010-03: 12195.5
# no month_base input. 2010-03: 116010.0
# no month_base input. 2010-04: 100111.0
# no month_base input. 2010-04: 119695.0
# no month_base input. 2010-04: 76067.5
# no month_base input. 2010-04: 12090.0
# no month_base input. 2010-04: 121745.5
# no month_base input. 2010-05: 96500.5
# no month_base input. 2010-05: 116216.5
# no month_base input. 2010-05: 76545.0
# no month_base input. 2010-05: 7802.0
# no month_base input. 2010-05: 124501.0
# no month_base input. 2010-06: 97103.5
# no month_base input. 2010-06: 120851.0
# no month_base input. 2010-06: 82470.5
# no month_base input. 2010-06: 10855.0
# no month_base input. 2010-06: 121944.5
# no month_base input. 2010-07: 96101.0
# no month_base input. 2010-07: 118001.5
# no month_base input. 2010-07: 82112.0
# no month_base input. 2010-07: 10295.5
# no month_base input. 2010-07: 121555.0
# no month_base input. 2010-08: 99749.5
# no month_base input. 2010-08: 128389.5
# no month_base input. 2010-08: 82450.5
# no month_base input. 2010-08: 11451.5
# no month_base input. 2010-08: 128600.5
# no month_base input. 2010-09: 103000.0
# no month_base input. 2010-09: 137889.0
# no month_base input. 2010-09: 83345.0
# no month_base input. 2010-09: 10800.5
# no month_base input. 2010-09: 140820.0
# no month_base input. 2010-10: 105000.0
# no month_base input. 2010-10: 148001.5
# no month_base input. 2010-10: 85345.0
# no month_base input. 2010-10: 11028.5
# no month_base input. 2010-10: 155002.0
# no month_base input. 2010-11: 90345.0
# no month_base input. 2010-11: 122668.5
# no month_base input. 2010-11: 75945.0
# no month_base input. 2010-11: 10445.0
# no month_base input. 2010-11: 130006.5
# no month_base input. 2010-12: 86510.0
# no month_base input. 2010-12: 120050.5
# no month_base input. 2010-12: 70212.0
# no month_base input. 2010-12: 9430.0
# no month_base input. 2010-12: 125888.0
# no month_base input. 2010-01: 73299.5
# no month_base input. 2010-01: 98505.0
# no month_base input. 2010-01: 67800.0
# no month_base input. 2010-01: 9211.5
# no month_base input. 2010-01: 107696.0
# no month_base input. 2010-02: 77900.5
# no month_base input. 2010-02: 99669.0
# no month_base input. 2010-02: 72501.0
# no month_base input. 2010-02: 9100.5
# no month_base input. 2010-02: 97053.5
# no month_base input. 2010-03: 84244.5
# no month_base input. 2010-03: 96010.5
# no month_base input. 2010-03: 72855.5
# no month_base input. 2010-03: 9544.5
# no month_base input. 2010-03: 95433.0
# no month_base input. 2010-04: 91505.0
# no month_base input. 2010-04: 101667.5
# no month_base input. 2010-04: 68001.5
# no month_base input. 2010-04: 9995.0
# no month_base input. 2010-04: 102125.5
# no month_base input. 2010-05: 93152.0
# no month_base input. 2010-05: 105345.5
# no month_base input. 2010-05: 71001.0
# no month_base input. 2010-05: 9407.0
# no month_base input. 2010-05: 104845.5
# no month_base input. 2010-06: 89544.5
# no month_base input. 2010-06: 101470.5
# no month_base input. 2010-06: 70244.5
# no month_base input. 2010-06: 8995.5
# no month_base input. 2010-06: 100800.0
# no month_base input. 2010-07: 91450.0
# no month_base input. 2010-07: 100450.5
# no month_base input. 2010-07: 70301.0
# no month_base input. 2010-07: 8994.5
# no month_base input. 2010-07: 100615.0
# no month_base input. 2010-08: 94094.5
# no month_base input. 2010-08: 105995.0
# no month_base input. 2010-08: 71750.0
# no month_base input. 2010-08: 9455.5
# no month_base input. 2010-08: 105620.0
# no month_base input. 2010-09: 97507.0
# no month_base input. 2010-09: 108150.5
# no month_base input. 2010-09: 74000.5
# no month_base input. 2010-09: 9850.5
# no month_base input. 2010-09: 110002.5
# no month_base input. 2010-10: 103349.5
# no month_base input. 2010-10: 114946.0
# no month_base input. 2010-10: 73974.0
# no month_base input. 2010-10: 9795.0
# no month_base input. 2010-10: 115350.0
# no month_base input. 2010-11: 94889.0
# no month_base input. 2010-11: 106541.0
# no month_base input. 2010-11: 68670.0
# no month_base input. 2010-11: 8879.0
# no month_base input. 2010-11: 108250.5
# no month_base input. 2010-12: 95000.0
# no month_base input. 2010-12: 106005.0
# no month_base input. 2010-12: 70089.5
# no month_base input. 2010-12: 8129.5
# no month_base input. 2010-12: 106496.5
# no month_base input. 2010-01: 93650.0
# no month_base input. 2010-01: 119063.0
# no month_base input. 2010-01: 66683.5
# no month_base input. 2010-01: 8361.0
# no month_base input. 2010-01: 119056.0
# no month_base input. 2010-02: 88925.0
# no month_base input. 2010-02: 110351.0
# no month_base input. 2010-02: 63847.5
# no month_base input. 2010-02: 8540.0
# no month_base input. 2010-02: 110001.0
# no month_base input. 2010-03: 93616.0
# no month_base input. 2010-03: 114945.0
# no month_base input. 2010-03: 68545.0
# no month_base input. 2010-03: 9356.0
# no month_base input. 2010-03: 114946.0
# no month_base input. 2010-04: 98612.0
# no month_base input. 2010-04: 117451.0
# no month_base input. 2010-04: 66891.5
# no month_base input. 2010-04: 9599.0
# no month_base input. 2010-04: 117501.5
# no month_base input. 2010-05: 102755.0
# no month_base input. 2010-05: 118439.0
# no month_base input. 2010-05: 62889.5
# no month_base input. 2010-05: 8708.0
# no month_base input. 2010-05: 118449.5
# no month_base input. 2010-06: 97561.5
# no month_base input. 2010-06: 114835.0
# no month_base input. 2010-06: 63500.0
# no month_base input. 2010-06: 8800.0
# no month_base input. 2010-06: 115394.5
# no month_base input. 2010-07: 101102.0
# no month_base input. 2010-07: 119350.5
# no month_base input. 2010-07: 67644.5
# no month_base input. 2010-07: 9450.0
# no month_base input. 2010-07: 119250.0
# no month_base input. 2010-08: 103266.5
# no month_base input. 2010-08: 123949.0
# no month_base input. 2010-08: 71095.5
# no month_base input. 2010-08: 8999.0
# no month_base input. 2010-08: 123667.5
# no month_base input. 2010-09: 113446.0
# no month_base input. 2010-09: 132195.5
# no month_base input. 2010-09: 72028.5
# no month_base input. 2010-09: 9155.0
# no month_base input. 2010-09: 134201.5
# no month_base input. 2010-10: 125052.5
# no month_base input. 2010-10: 136444.5
# no month_base input. 2010-10: 75551.0
# no month_base input. 2010-10: 9599.5
# no month_base input. 2010-10: 138004.5
# no month_base input. 2010-11: 109501.0
# no month_base input. 2010-11: 122445.5
# no month_base input. 2010-11: 76194.5
# no month_base input. 2010-11: 8664.5
# no month_base input. 2010-11: 123005.5
# no month_base input. 2010-01: 19501.5
# no month_base input. 2010-01: 20795.0
# no month_base input. 2010-01: 19545.5
# no month_base input. 2010-01: 870.5
# no month_base input. 2010-01: 20894.0
# no month_base input. 2010-02: 20164.5
# no month_base input. 2010-02: 23534.5
# no month_base input. 2010-02: 22445.5
# no month_base input. 2010-02: 926.5
# no month_base input. 2010-02: 23315.0
# no month_base input. 2010-03: 24595.5
# no month_base input. 2010-03: 31239.0
# no month_base input. 2010-03: 29945.5
# no month_base input. 2010-03: 1179.5
# no month_base input. 2010-03: 34795.5
# no month_base input. 2010-04: 32000.5
# no month_base input. 2010-04: 42751.0
# no month_base input. 2010-04: 36033.5
# no month_base input. 2010-04: 1237.0
# no month_base input. 2010-04: 46001.5
# no month_base input. 2010-05: 26745.5
# no month_base input. 2010-05: 36300.0
# no month_base input. 2010-05: 30945.0
# no month_base input. 2010-05: 1282.0
# no month_base input. 2010-05: 39001.0
# no month_base input. 2010-06: 30780.5
# no month_base input. 2010-06: 39956.5
# no month_base input. 2010-06: 30939.0
# no month_base input. 2010-06: 1453.0
# no month_base input. 2010-06: 41003.0
# no month_base input. 2010-07: 32831.5
# no month_base input. 2010-07: 39399.0
# no month_base input. 2010-07: 30995.0
# no month_base input. 2010-07: 1305.0
# no month_base input. 2010-07: 42287.5
# no month_base input. 2010-08: 30552.0
# no month_base input. 2010-08: 43072.0
# no month_base input. 2010-08: 30057.0
# no month_base input. 2010-08: 1276.0
# no month_base input. 2010-08: 43201.0
# no month_base input. 2010-09: 31545.0
# no month_base input. 2010-09: 43315.0
# no month_base input. 2010-09: 32000.5
# no month_base input. 2010-09: 1477.0
# no month_base input. 2010-09: 43645.5
# no month_base input. 2010-10: 32773.5
# no month_base input. 2010-10: 43700.5
# no month_base input. 2010-10: 30700.0
# no month_base input. 2010-10: 1595.5
# no month_base input. 2010-10: 44495.0
# no month_base input. 2010-11: 36500.5
# no month_base input. 2010-11: 46695.5
# no month_base input. 2010-11: 31104.0
# no month_base input. 2010-11: 1477.0
# no month_base input. 2010-11: 47945.5
# no month_base input. 2010-12: 46866.5
# no month_base input. 2010-12: 67251.5
# no month_base input. 2010-12: 32751.0
# no month_base input. 2010-12: 1626.0
# no month_base input. 2010-12: 70501.0
# no month_base input. 2010-01: 39506.0
# no month_base input. 2010-01: 63955.0
# no month_base input. 2010-01: 32555.5
# no month_base input. 2010-01: 1596.5
# no month_base input. 2010-01: 71399.0
# no month_base input. 2010-02: 40061.5
# no month_base input. 2010-02: 57700.0
# no month_base input. 2010-02: 28800.0
# no month_base input. 2010-02: 1910.0
# no month_base input. 2010-02: 60445.5
# no month_base input. 2010-03: 43206.5
# no month_base input. 2010-03: 59448.0
# no month_base input. 2010-03: 29845.5
# no month_base input. 2010-03: 2569.0
# no month_base input. 2010-03: 60541.5
# no month_base input. 2010-04: 43606.0
# no month_base input. 2010-04: 55901.0
# no month_base input. 2010-04: 26044.5
# no month_base input. 2010-04: 2496.0
# no month_base input. 2010-04: 56550.5
# no month_base input. 2010-05: 45889.5
# no month_base input. 2010-05: 56155.5
# no month_base input. 2010-05: 22439.0
# no month_base input. 2010-05: 2133.0
# no month_base input. 2010-05: 56689.5
# no month_base input. 2010-06: 51817.0
# no month_base input. 2010-06: 65350.0
# no month_base input. 2010-06: 30047.5
# no month_base input. 2010-06: 2390.5
# no month_base input. 2010-06: 63745.0
# no month_base input. 2010-07: 55995.5
# no month_base input. 2010-07: 70501.0
# no month_base input. 2010-07: 33546.0
# no month_base input. 2010-07: 2186.0
# no month_base input. 2010-07: 71650.5
# no month_base input. 2010-08: 49051.0
# no month_base input. 2010-08: 68205.5
# no month_base input. 2010-08: 33149.0
# no month_base input. 2010-08: 1944.5
# no month_base input. 2010-08: 68558.5
# no month_base input. 2010-09: 49503.0
# no month_base input. 2010-09: 63945.5
# no month_base input. 2010-09: 30994.5
# no month_base input. 2010-09: 2224.0
# no month_base input. 2010-09: 64045.5
# no month_base input. 2010-10: 53200.5
# no month_base input. 2010-10: 69744.5
# no month_base input. 2010-10: 34906.0
# no month_base input. 2010-10: 2084.5
# no month_base input. 2010-10: 69329.0
# no month_base input. 2010-11: 55442.0
# no month_base input. 2010-11: 77170.0
# ...
# no month_base input. 2010-09: 29104.5
# no month_base input. 2010-09: 31654.0
# no month_base input. 2010-09: 27052.5
# no month_base input. 2010-09: 4302.0
# no month_base input. 2010-09: 31900.5
# no month_base input. 2010-10: 27006.5
# no month_base input. 2010-10: 31301.5
# no month_base input. 2010-10: 29001.0
# no month_base input. 2010-10: 4030.0
# no month_base input. 2010-10: 32726.0
# no month_base input. 2010-11: 26599.5
# no month_base input. 2010-11: 31701.5
# no month_base input. 2010-11: 28505.0
# no month_base input. 2010-11: 2749.0
# no month_base input. 2010-11: 31479.5
# no month_base input. 2010-12: 24534.5
# no month_base input. 2010-12: 31001.0
# no month_base input. 2010-12: 27005.0
# no month_base input. 2010-12: 3594.0
# no month_base input. 2010-12: 31330.0
# no month_base input. 2010-01: 26045.0
# no month_base input. 2010-01: 33094.5
# no month_base input. 2010-01: 26616.0
# no month_base input. 2010-01: 3249.5
# no month_base input. 2010-01: 33299.0
# no month_base input. 2010-02: 25995.0
# no month_base input. 2010-02: 34956.0
# no month_base input. 2010-02: 26646.0
# no month_base input. 2010-02: 3699.0
# no month_base input. 2010-02: 35988.5
# no month_base input. 2010-03: 26484.0
# no month_base input. 2010-03: 38181.0
# no month_base input. 2010-03: 27015.5
# no month_base input. 2010-03: 3535.5
# no month_base input. 2010-03: 39310.0
# no month_base input. 2010-04: 31179.0
# no month_base input. 2010-04: 45551.0
# no month_base input. 2010-04: 29795.0
# no month_base input. 2010-04: 3476.5
# no month_base input. 2010-04: 50309.5
# no month_base input. 2010-05: 31852.0
# no month_base input. 2010-05: 45287.0
# no month_base input. 2010-05: 27979.5
# no month_base input. 2010-05: 3277.0
# no month_base input. 2010-05: 49751.0
# no month_base input. 2010-06: 28504.0
# no month_base input. 2010-06: 37817.0
# no month_base input. 2010-06: 25501.5
# no month_base input. 2010-06: 3045.0
# no month_base input. 2010-06: 40701.0
# no month_base input. 2010-07: 27628.0
# no month_base input. 2010-07: 36703.0
# no month_base input. 2010-07: 24844.0
# no month_base input. 2010-07: 3317.5
# no month_base input. 2010-07: 38395.0
# no month_base input. 2010-08: 32321.0
# no month_base input. 2010-08: 39301.5
# no month_base input. 2010-08: 27150.5
# no month_base input. 2010-08: 4350.5
# no month_base input. 2010-08: 40257.0
# no month_base input. 2010-09: 31771.0
# no month_base input. 2010-09: 36500.5
# no month_base input. 2010-09: 25529.0
# no month_base input. 2010-09: 3845.0
# no month_base input. 2010-09: 38956.0
# no month_base input. 2010-10: 33155.0
# no month_base input. 2010-10: 41583.0
# no month_base input. 2010-10: 26255.0
# no month_base input. 2010-10: 3844.5
# no month_base input. 2010-10: 41510.5
# no month_base input. 2010-11: 31000.0
# no month_base input. 2010-11: 39854.5
# no month_base input. 2010-11: 24947.0
# no month_base input. 2010-11: 4010.5
# no month_base input. 2010-11: 40495.0
# no month_base input. 2010-12: 32949.0
# no month_base input. 2010-12: 36950.0
# no month_base input. 2010-12: 23452.0
# no month_base input. 2010-12: 3723.5
# no month_base input. 2010-12: 38439.0
# no month_base input. 2010-01: 35165.0
# no month_base input. 2010-01: 37407.0
# no month_base input. 2010-01: 24701.5
# no month_base input. 2010-01: 4299.5
# no month_base input. 2010-01: 37750.0
# no month_base input. 2010-02: 31504.5
# no month_base input. 2010-02: 31889.5
# no month_base input. 2010-02: 25007.0
# no month_base input. 2010-02: 4355.0
# no month_base input. 2010-02: 34100.5
# no month_base input. 2010-03: 31954.5
# no month_base input. 2010-03: 31406.5
# no month_base input. 2010-03: 23102.0
# no month_base input. 2010-03: 4399.5
# no month_base input. 2010-03: 32500.0
# no month_base input. 2010-07: 33109.5
# no month_base input. 2010-07: 35445.0
# no month_base input. 2010-07: 24195.0
# no month_base input. 2010-07: 7106.0
# no month_base input. 2010-07: 34995.0
# no month_base input. 2010-08: 34355.0
# no month_base input. 2010-08: 37952.0
# no month_base input. 2010-08: 24553.0
# no month_base input. 2010-08: 7566.5
# no month_base input. 2010-08: 37306.0
# no month_base input. 2010-09: 38135.0
# no month_base input. 2010-09: 41249.5
# no month_base input. 2010-09: 27616.5
# no month_base input. 2010-09: 7365.0
# no month_base input. 2010-09: 40895.5
# no month_base input. 2010-10: 36934.0
# no month_base input. 2010-10: 40840.0
# no month_base input. 2010-10: 33433.5
# no month_base input. 2010-10: 7375.5
# no month_base input. 2010-10: 40095.0
# no month_base input. 2010-11: 36840.0
# no month_base input. 2010-11: 40050.5
# no month_base input. 2010-11: 30918.0
# no month_base input. 2010-11: 7275.5
# no month_base input. 2010-11: 40501.5
# no month_base input. 2010-12: 40635.0
# no month_base input. 2010-12: 47156.0
# no month_base input. 2010-12: 34045.0
# no month_base input. 2010-12: 7679.5
# no month_base input. 2010-12: 47505.0
# no month_base input. 2010-01: 42055.0
# no month_base input. 2010-01: 49550.5
# no month_base input. 2010-01: 38449.5
# no month_base input. 2010-01: 7545.0
# no month_base input. 2010-01: 50694.5
# no month_base input. 2010-02: 41500.5
# no month_base input. 2010-02: 46396.0
# no month_base input. 2010-02: 42945.5
# no month_base input. 2010-02: 7503.0
# no month_base input. 2010-02: 48642.0
# no month_base input. 2010-03: 43292.5
# no month_base input. 2010-03: 46001.0
# no month_base input. 2010-03: 38551.0
# no month_base input. 2010-03: 7771.5
# no month_base input. 2010-03: 47403.5
# no month_base input. 2010-04: 47620.0
# no month_base input. 2010-04: 56749.5
# no month_base input. 2010-04: 40067.5
# no month_base input. 2010-04: 8000.0
# no month_base input. 2010-04: 57150.0
# no month_base input. 2010-05: 44901.5
# no month_base input. 2010-05: 59045.0
# no month_base input. 2010-05: 42351.0
# no month_base input. 2010-05: 8356.0
# no month_base input. 2010-05: 62501.0
# no month_base input. 2010-06: 48165.5
# no month_base input. 2010-06: 58070.5
# no month_base input. 2010-06: 37001.0
# no month_base input. 2010-06: 8602.0
# no month_base input. 2010-06: 59556.5
# no month_base input. 2010-07: 46005.5
# no month_base input. 2010-07: 57800.5
# no month_base input. 2010-07: 39211.5
# no month_base input. 2010-07: 8595.5
# no month_base input. 2010-07: 58850.5
# no month_base input. 2010-08: 45939.0
# no month_base input. 2010-08: 58501.0
# no month_base input. 2010-08: 41299.5
# no month_base input. 2010-08: 9199.5
# no month_base input. 2010-08: 62250.0
# no month_base input. 2010-09: 47500.0
# no month_base input. 2010-09: 65455.0
# no month_base input. 2010-09: 39500.5
# no month_base input. 2010-09: 9389.0
# no month_base input. 2010-09: 67351.0
# no month_base input. 2010-10: 49855.0
# no month_base input. 2010-10: 75205.0
# no month_base input. 2010-10: 39695.5
# no month_base input. 2010-10: 9181.0
# no month_base input. 2010-10: 78878.0
# no month_base input. 2010-11: 54355.0
# no month_base input. 2010-11: 81201.0
# no month_base input. 2010-11: 42751.5
# no month_base input. 2010-11: 9381.0
# no month_base input. 2010-11: 87000.5
# no month_base input. 2010-12: 57905.5
# no month_base input. 2010-12: 80695.0
# no month_base input. 2010-12: 44500.0
# no month_base input. 2010-12: 9501.0
# no month_base input. 2010-12: 84444.5
# no month_base input. 2010-01: 57748.5
# no month_base input. 2010-01: 79850.5
# no month_base input. 2010-01: 42600.5
# no month_base input. 2010-01: 9844.5
# no month_base input. 2010-01: 83206.0
# no month_base input. 2010-02: 61880.5
# no month_base input. 2010-02: 89846.0
# no month_base input. 2010-02: 45251.0
# no month_base input. 2010-02: 10299.5
# no month_base input. 2010-02: 90051.0
# no month_base input. 2010-03: 70028.5
# no month_base input. 2010-03: 96889.0
# no month_base input. 2010-03: 50196.5
# no month_base input. 2010-03: 10950.5
# no month_base input. 2010-03: 98950.0
# no month_base input. 2010-04: 70847.5
# no month_base input. 2010-04: 94195.5
# no month_base input. 2010-04: 53451.5
# no month_base input. 2010-04: 10152.0
# no month_base input. 2010-04: 97900.0
# no month_base input. 2010-05: 69451.0
# no month_base input. 2010-05: 93989.5
# no month_base input. 2010-05: 51195.5
# no month_base input. 2010-05: 9489.5
# no month_base input. 2010-05: 93506.5
# no month_base input. 2010-06: 74395.0
# no month_base input. 2010-06: 103342.5
# no month_base input. 2010-06: 53006.5
# no month_base input. 2010-06: 10151.0
# no month_base input. 2010-06: 102548.5
# no month_base input. 2010-07: 78450.0
# no month_base input. 2010-07: 108901.5
# no month_base input. 2010-07: 54445.0
# no month_base input. 2010-07: 10899.5
# no month_base input. 2010-07: 112262.5
# no month_base input. 2010-08: 83944.5
# no month_base input. 2010-08: 109501.0
# no month_base input. 2010-08: 57589.5
# no month_base input. 2010-08: 11050.5
# no month_base input. 2010-08: 112500.5
# no month_base input. 2010-09: 85000.0
# no month_base input. 2010-09: 110525.5
# no month_base input. 2010-09: 65995.0
# no month_base input. 2010-09: 11445.0
# no month_base input. 2010-09: 110250.0
# no month_base input. 2010-10: 80795.0
# no month_base input. 2010-10: 102928.0
# no month_base input. 2010-10: 68096.0
# no month_base input. 2010-10: 12276.0
# no month_base input. 2010-10: 106502.0
# no month_base input. 2010-11: 88912.0
# no month_base input. 2010-11: 114634.5
# no month_base input. 2010-11: 79052.0
# no month_base input. 2010-11: 12889.0
# no month_base input. 2010-11: 115293.0
# no month_base input. 2010-12: 88255.0
# no month_base input. 2010-12: 106753.5
# no month_base input. 2010-12: 79850.5
# no month_base input. 2010-12: 11895.0
# no month_base input. 2010-12: 110062.0
# no month_base input. 2010-01: 83000.0
# no month_base input. 2010-01: 103730.5
# no month_base input. 2010-01: 77205.0
# no month_base input. 2010-01: 10995.5
# no month_base input. 2010-01: 107444.5
# no month_base input. 2010-02: 86278.0
# no month_base input. 2010-02: 110262.5
# no month_base input. 2010-02: 86454.5
# no month_base input. 2010-02: 11895.5
# no month_base input. 2010-02: 111501.5
# no month_base input. 2010-03: 90751.5
# no month_base input. 2010-03: 115851.0
# no month_base input. 2010-03: 88245.0
# no month_base input. 2010-03: 12195.5
# no month_base input. 2010-03: 116010.0
# no month_base input. 2010-04: 100111.0
# no month_base input. 2010-04: 119695.0
# no month_base input. 2010-04: 76067.5
# no month_base input. 2010-04: 12090.0
# no month_base input. 2010-04: 121745.5
# no month_base input. 2010-05: 96500.5
# no month_base input. 2010-05: 116216.5
# no month_base input. 2010-05: 76545.0
# no month_base input. 2010-05: 7802.0
# no month_base input. 2010-05: 124501.0
# no month_base input. 2010-06: 97103.5
# no month_base input. 2010-06: 120851.0
# no month_base input. 2010-06: 82470.5
# no month_base input. 2010-06: 10855.0
# no month_base input. 2010-06: 121944.5
# no month_base input. 2010-07: 96101.0
# no month_base input. 2010-07: 118001.5
# no month_base input. 2010-07: 82112.0
# no month_base input. 2010-07: 10295.5
# no month_base input. 2010-07: 121555.0
# no month_base input. 2010-08: 99749.5
# no month_base input. 2010-08: 128389.5
# no month_base input. 2010-08: 82450.5
# no month_base input. 2010-08: 11451.5
# no month_base input. 2010-08: 128600.5
# no month_base input. 2010-09: 103000.0
# no month_base input. 2010-09: 137889.0
# no month_base input. 2010-09: 83345.0
# no month_base input. 2010-09: 10800.5
# no month_base input. 2010-09: 140820.0
# no month_base input. 2010-10: 105000.0
# no month_base input. 2010-10: 148001.5
# no month_base input. 2010-10: 85345.0
# no month_base input. 2010-10: 11028.5
# no month_base input. 2010-10: 155002.0
# no month_base input. 2010-11: 90345.0
# no month_base input. 2010-11: 122668.5
# no month_base input. 2010-11: 75945.0
# no month_base input. 2010-11: 10445.0
# no month_base input. 2010-11: 130006.5
# no month_base input. 2010-12: 86510.0
# no month_base input. 2010-12: 120050.5
# no month_base input. 2010-12: 70212.0
# no month_base input. 2010-12: 9430.0
# no month_base input. 2010-12: 125888.0
# no month_base input. 2010-01: 73299.5
# no month_base input. 2010-01: 98505.0
# no month_base input. 2010-01: 67800.0
# no month_base input. 2010-01: 9211.5
# no month_base input. 2010-01: 107696.0
# no month_base input. 2010-02: 77900.5
# no month_base input. 2010-02: 99669.0
# no month_base input. 2010-02: 72501.0
# no month_base input. 2010-02: 9100.5
# no month_base input. 2010-02: 97053.5
# no month_base input. 2010-03: 84244.5
# no month_base input. 2010-03: 96010.5
# no month_base input. 2010-03: 72855.5
# no month_base input. 2010-03: 9544.5
# no month_base input. 2010-03: 95433.0
# no month_base input. 2010-04: 91505.0
# no month_base input. 2010-04: 101667.5
# no month_base input. 2010-04: 68001.5
# no month_base input. 2010-04: 9995.0
# no month_base input. 2010-04: 102125.5
# no month_base input. 2010-05: 93152.0
# no month_base input. 2010-05: 105345.5
# no month_base input. 2010-05: 71001.0
# no month_base input. 2010-05: 9407.0
# no month_base input. 2010-05: 104845.5
# no month_base input. 2010-06: 89544.5
# no month_base input. 2010-06: 101470.5
# no month_base input. 2010-06: 70244.5
# no month_base input. 2010-06: 8995.5
# no month_base input. 2010-06: 100800.0
# no month_base input. 2010-07: 91450.0
# no month_base input. 2010-07: 100450.5
# no month_base input. 2010-07: 70301.0
# no month_base input. 2010-07: 8994.5
# no month_base input. 2010-07: 100615.0
# no month_base input. 2010-08: 94094.5
# no month_base input. 2010-08: 105995.0
# no month_base input. 2010-08: 71750.0
# no month_base input. 2010-08: 9455.5
# no month_base input. 2010-08: 105620.0
# no month_base input. 2010-09: 97507.0
# no month_base input. 2010-09: 108150.5
# no month_base input. 2010-09: 74000.5
# no month_base input. 2010-09: 9850.5
# no month_base input. 2010-09: 110002.5
# no month_base input. 2010-10: 103349.5
# no month_base input. 2010-10: 114946.0
# no month_base input. 2010-10: 73974.0
# no month_base input. 2010-10: 9795.0
# no month_base input. 2010-10: 115350.0
# no month_base input. 2010-11: 94889.0
# no month_base input. 2010-11: 106541.0
# no month_base input. 2010-11: 68670.0
# no month_base input. 2010-11: 8879.0
# no month_base input. 2010-11: 108250.5
# no month_base input. 2010-12: 95000.0
# no month_base input. 2010-12: 106005.0
# no month_base input. 2010-12: 70089.5
# no month_base input. 2010-12: 8129.5
# no month_base input. 2010-12: 106496.5
# no month_base input. 2010-01: 93650.0
# no month_base input. 2010-01: 119063.0
# no month_base input. 2010-01: 66683.5
# no month_base input. 2010-01: 8361.0
# no month_base input. 2010-01: 119056.0
# no month_base input. 2010-02: 88925.0
# no month_base input. 2010-02: 110351.0
# no month_base input. 2010-02: 63847.5
# no month_base input. 2010-02: 8540.0
# no month_base input. 2010-02: 110001.0
# no month_base input. 2010-03: 93616.0
# no month_base input. 2010-03: 114945.0
# no month_base input. 2010-03: 68545.0
# no month_base input. 2010-03: 9356.0
# no month_base input. 2010-03: 114946.0
# no month_base input. 2010-04: 98612.0
# no month_base input. 2010-04: 117451.0
# no month_base input. 2010-04: 66891.5
# no month_base input. 2010-04: 9599.0
# no month_base input. 2010-04: 117501.5
# no month_base input. 2010-05: 102755.0
# no month_base input. 2010-05: 118439.0
# no month_base input. 2010-05: 62889.5
# no month_base input. 2010-05: 8708.0
# no month_base input. 2010-05: 118449.5
# no month_base input. 2010-06: 97561.5
# no month_base input. 2010-06: 114835.0
# no month_base input. 2010-06: 63500.0
# no month_base input. 2010-06: 8800.0
# no month_base input. 2010-06: 115394.5
# no month_base input. 2010-07: 101102.0
# no month_base input. 2010-07: 119350.5
# no month_base input. 2010-07: 67644.5
# no month_base input. 2010-07: 9450.0
# no month_base input. 2010-07: 119250.0
# no month_base input. 2010-08: 103266.5
# no month_base input. 2010-08: 123949.0
# no month_base input. 2010-08: 71095.5
# no month_base input. 2010-08: 8999.0
# no month_base input. 2010-08: 123667.5
# no month_base input. 2010-09: 113446.0
# no month_base input. 2010-09: 132195.5
# no month_base input. 2010-09: 72028.5
# no month_base input. 2010-09: 9155.0
# no month_base input. 2010-09: 134201.5
# no month_base input. 2010-10: 125052.5
# no month_base input. 2010-10: 136444.5
# no month_base input. 2010-10: 75551.0
# no month_base input. 2010-10: 9599.5
# no month_base input. 2010-10: 138004.5
# no month_base input. 2010-11: 109501.0
# no month_base input. 2010-11: 122445.5
# no month_base input. 2010-11: 76194.5
# no month_base input. 2010-11: 8664.5
# no month_base input. 2010-11: 123005.5

# %%
x = df_cpi_trim['month']
plt.plot(x, df_cpi_trim['cpi_reindexed_monthly'], label='CPI', color='black')
plt.plot(x, df_coe_a_trim['coe_indexed_monthly'], label='Cat A', color='blue')
plt.plot(x, df_coe_b_trim['coe_indexed_monthly'], label='Cat B', color='green')
plt.plot(x, df_coe_d_trim['coe_indexed_monthly'], label='Cat D', color='red')

plt.title('CPI vs COE categories (indexed to 2010 by months)')
#plt.xlabel('Months')
plt.ylabel('Price Index')
#plt.yscale('log') # Set the y-axis to a logarithmic scale
plt.legend()
plt.tick_params(axis='x', labelrotation=0)

plt.show()

# %%
x = df_cpi_trim['month']
plt.plot(x, df_cpi_trim['cpi_reindexed_2010-01'], label='CPI', color='black')
plt.plot(x, df_coe_a_trim['coe_indexed_2010-01'], label='Cat A', color='blue')
plt.plot(x, df_coe_b_trim['coe_indexed_2010-01'], label='Cat B', color='green')
plt.plot(x, df_coe_d_trim['coe_indexed_2010-01'], label='Cat D', color='red')

plt.title('CPI vs COE categories (indexed to 2010-01)')
#plt.xlabel('Months')
plt.ylabel('Price Index')
#plt.yscale('log') # Set the y-axis to a logarithmic scale
plt.legend()
plt.tick_params(axis='x', labelrotation=0)

plt.show()

# %%
df_cpi_trim.head(25)
# Out:
#          month All Items  cpi_reindexed_monthly  cpi_reindexed_2010-01
# 190 2010-01-01     73.64                100.000                100.000
# 189 2010-02-01    73.771                100.000                100.000
# 188 2010-03-01        74                100.000                100.000
# 187 2010-04-01    74.596                100.000                100.000
# 186 2010-05-01    75.025                100.000                100.000
# 185 2010-06-01    74.662                100.000                100.000
# 184 2010-07-01    75.261                100.000                100.000
# 183 2010-08-01    75.608                100.000                100.000
# 182 2010-09-01    75.678                100.000                100.000
# 181 2010-10-01    75.991                100.000                100.000
# 180 2010-11-01    76.243                100.000                100.000
# 179 2010-12-01    76.692                100.000                100.000
# 178 2011-01-01    77.517                105.265                105.265
# 177 2011-02-01    77.549                105.121                105.121
# 176 2011-03-01    77.623                104.896                104.896
# 175 2011-04-01    78.449                105.165                105.165
# 174 2011-05-01    78.348                104.429                104.429
# 173 2011-06-01    78.535                105.187                105.187
# 172 2011-07-01    79.317                105.389                105.389
# 171 2011-08-01    79.888                105.661                105.661
# 170 2011-09-01    79.754                105.386                105.386
# 169 2011-10-01    80.066                105.362                105.362
# 168 2011-11-01    80.512                105.599                105.599
# 167 2011-12-01    80.898                105.484                105.484
# 166 2012-01-01     81.34                110.456                110.456

# %%
df_coe_a_trim.head(25)
# Out:
#          month vehicle_class   quota  bids_success  bids_received  premium  \
# 0   2010-01-01    Category A  1151.5        1147.0         1507.5  19501.5
# 5   2010-02-01    Category A  1151.0        1150.5         1409.5  20164.5
# 10  2010-03-01    Category A  1147.0        1139.0         1970.5  24595.5
# 15  2010-04-01    Category A   705.5         650.5         1310.5  32000.5
# 20  2010-05-01    Category A   752.5         747.5         1165.0  26745.5
# 25  2010-06-01    Category A   702.5         700.5         1004.5  30780.5
# 30  2010-07-01    Category A   699.5         683.5          930.0  32831.5
# 35  2010-08-01    Category A   614.0         597.5          880.5  30552.0
# 40  2010-09-01    Category A   614.0         587.5          884.0  31545.0
# 45  2010-10-01    Category A   624.0         624.0          769.5  32773.5
# 50  2010-11-01    Category A   597.5         587.5          838.0  36500.5
# 55  2010-12-01    Category A   607.5         594.5          887.5  46866.5
# 60  2011-01-01    Category A   610.5         604.0         1141.5  39506.0
# 65  2011-02-01    Category A   517.0         497.5          967.0  40061.5
# 70  2011-03-01    Category A   529.5         501.0          901.0  43206.5
# 75  2011-04-01    Category A   538.5         531.5          888.5  43606.0
# 80  2011-05-01    Category A   517.0         516.0          852.0  45889.5
# 85  2011-06-01    Category A   511.0         509.0          797.5  51817.0
# 90  2011-07-01    Category A   512.0         499.0          807.5  55995.5
# 95  2011-08-01    Category A   561.5         561.5          980.5  49051.0
# 100 2011-09-01    Category A   548.0         539.0          872.5  49503.0
# 105 2011-10-01    Category A   557.0         551.5          833.0  53200.5
# 110 2011-11-01    Category A   553.5         544.0          761.0  55442.0
# 115 2011-12-01    Category A   557.5         500.0          829.5  51196.5
# 120 2012-01-01    Category A   605.5         603.0          902.0  47500.5
#
#      coe_indexed
# 0        100.000
# 5        100.000
# 10       100.000
# 15       100.000
# 20       100.000
# 25       100.000
# 30       100.000
# 35       100.000
# 40       100.000
# 45       100.000
# 50       100.000
# 55       100.000
# 60       202.579
# 65       198.673
# 70       175.668
# 75       136.267
# 80       171.578
# 85       168.344
# 90       170.554
# 95       160.549
# 100      156.928
# 105      162.328
# 110      151.894
# 115      109.239
# 120      243.574

# %%
# Process vehicle registration and deregistration datasets
registered_prep = basicprep_vehregs(registered, 4, 4)
deregistered_prep = basicprep_vehregs(deregistered, 4, 4)

# Trim datasets to only the common dates so that we can plot
df_list = [df_coe_a_trim, registered_prep, deregistered_prep] #use df_coe_a_trim as reference
common_dates = get_common_dates(df_list, 'month')
df_registered_trim = registered_prep[registered_prep['month'].isin(common_dates)]
df_deregistered_trim = deregistered_prep[deregistered_prep['month'].isin(common_dates)]

# Combined both datasets to get net registrations
net_registrations = pd.merge(df_registered_trim,df_deregistered_trim, how='inner', on='month', suffixes=('_registered', '_deregistered'))

for category in ['Category A', 'Category B', 'Category D']:
    net_registrations[f'Net {category}'] = net_registrations[f'{category}_registered'] - net_registrations[f'{category}_deregistered']
    net_registrations.drop(columns=[f'{category}_registered', f'{category}_deregistered'], inplace=True)

net_registrations
# Out:
#          month  Net Category A  Net Category B  Net Category D
# 0   2025-11-01             114              61             483
# 1   2025-10-01            -562            -181             297
# 2   2025-09-01             259             171             594
# 3   2025-08-01            -134            -151             329
# 4   2025-07-01             451              91             256
# ..         ...             ...             ...             ...
# 183 2010-05-01             354             917             -19
# 184 2010-04-01             591             970              38
# 185 2010-03-01             754             869             126
# 186 2010-02-01             536            1204             173
# 187 2010-01-01            1764            1497             180
#
# [188 rows x 4 columns]

# %%
x = net_registrations['month']
#plt.plot(x, net_registrations['Net Category A'], label='Net Reg (A)', color='cornflowerblue',  linestyle='--')
plt.plot(x, net_registrations['Net Category B'], label='Net Reg (B)', color='springgreen',  linestyle='--')
#plt.plot(x, net_registrations['Net Category D'], label='Net Reg (D)', color='lightcoral',  linestyle='--')
#plt.plot(x, df_coe_a_trim['quota'], label='Quota (A)', color='blue', linestyle='-')
plt.plot(x, df_coe_b_trim['quota'], label='Quota (B)', color='green', linestyle='-')
#plt.plot(x, df_coe_d_trim['quota'], label='Quota (D)', color='red', linestyle='-')

plt.title('Net Registrations vs Quotas')
#plt.xlabel('Months')
plt.ylabel('Quanitity')
plt.yscale('linear') # Set the y-axis to a linear scale
plt.legend()
plt.tick_params(axis='x', labelrotation=0)

plt.show()

# %%
def plot_twin_axis(x, y1, y2, y1_label, y2_label, title):
    fig, ax1 = plt.subplots()

    colour_ax1 = 'tab:blue'
    ax1.set_xlabel('Month')
    ax1.set_ylabel(y1_label, color=colour_ax1)
    ax1.plot(x, y1, color=colour_ax1)
    ax1.tick_params(axis='y', labelcolor=colour_ax1)

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    colour_ax2 = 'tab:red'
    ax2.set_ylabel(y2_label, color=colour_ax2)  # we already handled the x-label with ax1
    ax2.plot(x, y2, color=colour_ax2)
    ax2.tick_params(axis='y', labelcolor=colour_ax2)

    plt.xticks(rotation=90)
    ax1.autoscale(enable=True, axis='x')
    ax2.autoscale(enable=True, axis='x')
    ax1.set_yscale('log')
    ax2.set_yscale('log')

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.title(title)
    plt.show()

plot_twin_axis(df_cpi_trim['month'], df_coe_d_trim['coe_indexed'], df_cpi_trim['cpi_reindexed'], 'Cat A', 'CPI', 'title')
